# %%
from bs4 import BeautifulSoup  # For HTML parsing
import datetime
from tinydb import TinyDB, Query
import urllib3   # Website connections
import xlsxwriter
import requests
import pandas as pd  # For converting results to a dataframe and bar chart plots
import time
import lxml
import re

# %%
url = 'https://au.indeed.com/jobs?q=data+scientist&l=Sydney+NSW'
job = requests.get(url)

soup = BeautifulSoup(job.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
#   <script src="/s/ab2a39a/en_AU.js" type="text/javascript">
#   </script>
#   <link href="/s/970d98c/jobsearch_all.css" rel="stylesheet" type="text/css"/>
#   <link href="http://au.indeed.com/rss?q=data+scientist&amp;l=Sydney+NSW" rel="alternate" title="Data Scientist Jobs in Sydney NSW" type="application/rss+xml"/>
#   <link href="/m/jobs?q=data+scientist&amp;l=Sydney+NSW" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <link href="/m/jobs?q=data+scientist&amp;l=Sydney+NSW" media="handheld" rel="alternate"/>
#   <script type="text/javascript">
#    if (typeof window['closureReadyCallbacks'] == 'undefined') {
#         window['closureReadyCallbacks'] = [];
#     }
#
#     function call_when_jsall_loaded(cb) {
#         if (window['closureReady']) {
#             cb();
#         } else {
#             window['closureReadyCallbacks'].push(cb);
#         }
#     }
#   </script>
#   <meta content="1" name="ppstriptst"/>
#   <script src="/s/c700df3/jobsearch-all-compiled.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var searchUID = '1crciuptq108c002';
# var tk = '1crciuptq108c002';
#
# var loggedIn = false;
# var dcmPayload = 'jobse0;jobal0;viewj0;savej0;8232301';
# var myindeed = true;
# var userEmail = '';
# var tellFriendEmail = '';
# var globalLoginURL = 'https:\/\/au.indeed.com\/account\/login?dest=%2Fdata-scientist-jobs-in-Sydney-NSW';
# var globalRegisterURL = 'https:\/\/au.indeed.com\/account\/register?dest=%2Fdata-scientist-jobs-in-Sydney-NSW';
# var searchKey = '0a66569993a94716';
# var searchState = 'q=data+scientist&amp;l=Sydney+NSW';
# var searchQS = 'q=data+scientist&l=Sydney+NSW';
# var eventType = 'jobsearch';
# var locale = 'en_AU';
# function clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1crciuptq108c002&jsa=4586'; a.href = jsh; }
# function sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }
# function sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }
# function ptk(st,p) {document.cookie = 'PTK="tk=1crciuptq108c002&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}
# function rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}
#   </script>
#   <script type="text/javascript">
#    function loadJSAsync( ) {
# 		for ( var i = 0; i < arguments.length; i++ ) {
# 			var url = arguments[i];
# 			(function() {
# 				var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
# 				s.async = true;
# 				s.src = url;
# 				el.parentNode.insertBefore(s, el);
# 			})();
# 		}
# 	}
#   </script>
#   <meta content="Data Scientist jobs now available in Sydney NSW. Data Scientist, Junior Data Scientist, Machine Learning Engineer and more on Indeed.com" name="description"/>
#   <meta content="Data Scientist Jobs in Sydney NSW, Sydney NSW careers, Sydney NSW employment, Sydney NSW job listings, Sydney NSW job search, Sydney NSW search engine, work in Sydney NSW" name="keywords"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <link href="/Data-Scientist-jobs-in-Sydney-NSW" rel="canonical"/>
#   <link href="/jobs?q=data+scientist&amp;l=Sydney+NSW&amp;start=10" rel="next"/>
#   <style type="text/css">
#    #recPromoDisplay { margin-bottom: 3em;margin-left: 0.5em; }
#         #recPromoDisplay a { padding-right: 8px; }
#         #recPromoDisplayPageLast { font-size: 16px; margin: 1.5em 0; }
#   </style>
#   <script type="text/javascript">
#    var dcmPayload = 'jobse0;jobal0;viewj0;savej0;8232301';
#     var indeedCsrfToken = 'rElgx1qUJNZEVGWAfFhTTv0sZYSkejDg';
#     var hashedCsrfToken = '6058b88e80973fad4a60e3cd3a48580d';
#   </script>
#   <style type="text/css">
#    .jasxcustomfonttst-useCustomHostedFontFullPage *{font-family:"Open Sans", sans-serif !important}.jasxcustomfonttst-useLato *{font-family:"Lato", sans-serif !important}.jasxcustomfonttst-useFira *{font-family:"Fira Sans", sans-serif !important}.jasxcustomfonttst-useGibson *{font-family:"Gibson", sans-serif !important}.jasxcustomfonttst-useAvenir *{font-family:"Avenir Next", sans-serif !important}#accessibilityBanner{position:absolute;left:-10000%;height:50px;width:100%;color:#000;font-size:13px;font-family:Arial;background-color:#F2F2F2;border-width:1px;border-color:#E6E6E6;line-height:50px}#accessibilityText{position:relative;left:12px;white-space:nowrap}#accessibilityClose{position:absolute;right:12px}#recOnSerpZrpBody{padding:0 20px 0 20px;min-height:60em}#recOnSerpZrpBody-Logo{max-height:400px}#recOnSerpZrpBody-Header{margin-top:50px;font-weight:700;font-size:18px;color:#000000;letter-spacing:-0.06px;line-height:24px}#recOnSerpZrpBody-Content{font-size:14px;color:#4B4B4B;letter-spacing:0;line-height:20px;margin-top:20px}.no_results{width:100% !important}#serpTabNav{margin:10px 0 10px 20px;border-bottom:1px solid #ccc;font-size:13px;display:flex}#serpTabNav .tab{padding:15px 10px 15px 10px}#serpTabNav .tab a{font-size:14px;line-height:20px;padding:12px 0 20px 0;color:#000 !important;text-decoration:none;position:relative}#serpTabNav .tab a:after{content:'';border-bottom:2px solid transparent;position:absolute;bottom:1px;left:0;right:0}#serpTabNav .tab a:hover:after{border-color:#1497ff}#serpTabNav .tab a.selected:after{border-color:#2164f3}#serpTabNav .tab a.selected{font-weight:700}#serpTabNav .tab .jobCount{background:#ECECEC;border-radius:100px;padding:5px 10px 5px 10px;margin-left:5px;font-weight:initial}#serpTabNav .tab .noJobCount{display:none}@media only screen and (min-width: 1250px){#serpTabNav{width:685px}}#serpTabNav{width:665px}@media only screen and (min-width: 1366px){#serpTabNav{width:745px}}@media only screen and (min-width: 1740px){#serpTabNav{width:860px}}#auxCol.on_zrp{width:665px}@media only screen and (min-width: 1366px){#auxCol.on_zrp{width:745px}}@media only screen and (min-width: 1740px){#auxCol.on_zrp{width:860px}}.jobFilterOnLeftRail{font-size:10pt;margin-left:6px;margin-bottom:1em}.jobFilterOnLeftRail-nowrap{white-space:nowrap}body.janus #serpTabNav{border-bottom:2px solid #f6f6f6;background-color:#fff;margin:unset;padding-left:15px}body.janus #serpTabNav{width:707px}@media only screen and (min-width: 1366px){body.janus #serpTabNav{width:768px}}@media only screen and (min-width: 1740px){body.janus #serpTabNav{width:884px}}body.janus #auxCol.on_zrp{width:542px}@media only screen and (min-width: 1366px){body.janus #auxCol.on_zrp{width:482px}}@media only screen and (min-width: 1740px){body.janus #auxCol.on_zrp{width:366px}}body.janus .jobFilterOnLeftRail{font-size:14px;font-weight:500;color:#000 !important}body.janus .jobFilterOnLeftRail-nowrap{display:block;font-size:12px;margin-top:4px;margin-bottom:24px}body.janus .jobFilterOnLeftRail-nowrap b{font-weight:500 !important}body.janus #resultsCol.on_zrp{min-width:430px}#footer #secondary_nav.jasxdebestsealtst-bottom{text-align:left;padding-left:20px}#footer #secondary_nav.jasxdebestsealtst-bottom #links_and_seal{display:flex;flex-direction:row-reverse}#footer #secondary_nav.jasxdebestsealtst-bottom .gaj_heading{margin-left:-1em}.icl-Button--xl{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:1.25rem;letter-spacing:-.1px;font-weight:700;line-height:1.3}[dir] .icl-Button--xl{padding-top:.5rem;padding-bottom:.5rem}[dir=ltr] .icl-Button--xl,[dir=rtl] .icl-Button--xl{padding-left:1.5rem;padding-right:1.5rem}.icl-Button,.icl-Button--lg{font-family:Helvetica Neue,Helvetica,Arial,Liberation Sans,Roboto,Noto,sans-serif;font-size:1rem;letter-spacing:0;font-weight:700;line-height:1.38;line-height:1.125rem}[dir] .icl-Button,[dir] .icl-Button--lg{padding-top:1rem;padding-bottom:1rem}[dir=ltr] .icl-Button,[dir=ltr] .icl- ...
#   </style>
#   <style type="text/css">
#    span.salary-legal-disclaimer-icon {
#     background-image: url('data:image/png;base64,...');
#     vertical-align: middle;
#     display: inline-block;
#     background-size: 13px 13px;
#     width: 13px;
#     height: 13px;
# }
#
# span.salary-legal-disclaimer-icon:hover {
#     cursor: pointer;
# }
#
# .salary-legal-disclaimer-container-group {
#     display: none;
#     position: fixed;
#     width: 100%;
#     height: 100%;
#     left: 0;
#     top: 0;
#     background-color: rgba(0, 0, 0, 0.3);
#     filter: progid:DXImageTransform.Microsoft.Gradient(GradientType=0, StartColorStr=#50000000, EndColorStr=#50000000); /* IE8 */
#     z-index: 1000;
# }
#
# .salary-legal-disclaimer-modal {
#     position: absolute;
#     box-sizing: border-box;
#     width: 500px;
#     height: 400px;
#     left: 0;
#     right: 0;
#     top: 0;
#     bottom: 0;
#     margin: auto;
#     background-color: #fff;
#     padding: 25px;
#     overflow: auto;
#     box-shadow: 0 0 8px rgba(0, 0, 0, 0.4);
# }
#
# #salary-legal-disclaimer-container-distribution .salary-legal-disclaimer-modal {
#     height: 250px;
# }
#
# .salary-legal-disclaimer-modal-close {
#     position: absolute;
#     right: 15px;
#     top: 15px;
#     width: 16px;
#     height: 16px;
#     opacity: .5;
#     cursor: pointer;
# }
#
# .salary-legal-disclaimer-modal-close:hover {
#     opacity: 1;
# }
#
# .salary-legal-disclaimer-modal-close:before,
# .salary-legal-disclaimer-modal-close:after {
#     display: inline-block;
#     content: "";
#     position: absolute;
#     left: 0;
#     top: 7px;
#     width: 16px;
#     height: 2px;
#     background-color: #666;
# }
#
# .salary-legal-disclaimer-modal-close:before {
#     -webkit-transform: rotate(45deg);
#     transform: rotate(45deg);
# }
#
# .salary-legal-disclaimer-modal-close:after {
#     -webkit-transform: rotate(-45deg);
#     transform: rotate(-45deg);
# }
#
# .salary-legal-disclaimer-content {
#     font: 13px/1.4 Arial, sans-serif;
#     color: black;
# }
#
# .salary-legal-disclaimer-title {
#     padding-bottom: 25px;
#     padding-top: 5px;
#     font-size: 18px;
#     font-weight: bold;
# }
#
# .salary-legal-disclaimer-link-wrap {
#     white-space: nowrap;
# }
#
# .salary-legal-disclaimer-link {
#     color: #0000cc;
# }
#   </style>
#   <style type="text/css">
#    #resultsCol { padding-top: 0; }
#     .searchCount { margin-top: 6px; }
#     .showing { padding-top: 9px; padding-bottom: 9px; }
#
#     .brdr { height: 1px; overflow: hidden; background-color: #ccc; }
#
#     /* Tall window sizes */
#     @media only screen and (min-height:780px){
#         .showing { padding-bottom: 0; }
#     }
#
#     /* Wide window sizes */
#     @media only screen and (min-width:1125px){
#         .brdr  { margin-left: 12px; margin-right: 12px; }
#     }
#
#     a, a:link, .link, .btn, .btn:hover { text-decoration:none; }
# a:hover, .link:hover { text-decoration:underline; }
# .dya-container a { text-decoration: underline!important; }
#   </style>
#   <script>
#    function onLoadHandler() {
#             initJavascriptGroups([[-1,null],[1,null],[-1,null],[3,null],[1,null],[2,null],[1,null],[1,null],[-1,null],[0,[]],[-1,null],[-1,null],[-1,[]],[-1,null],[-1,null],[-1,["disableEmptyQueryByDefault"]],[-1,null],[-1,[]],[10,["serp:enableEmptyQuery","serp:suggestOnFocus","requestOnFocus"]],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[8,null],[2,null],[1,null],[7,null],[-1,null],[0,null],[0,null],[0,null],[8,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[3,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,"AUSTIN_DUBLIN"],[-1,null],[1,null],[-1,null],[-1,null],[-1,[]],[-1,null],[-1,null],[2,null],[1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[1,0],[2,["logOnlyTestGroup:false","sjErevStatType:min","erevScaleFactor:1","multiCurrencyComparisonEnabled:true"]],[1,1],[-1,""],[-1,null],[4,null],[10,null],[1,null],[-1,null],[-1,null],[6,null],[2,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[32,[8050739,8913675,9355776]],[-1,null],[2,null],[-1,null],[-1,null],[1,null],[1,null],[1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[0,null],[1,null],[1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[3,7],[-1,null],[1,null],[-1,null],[-1,null],[-1,0.0],[2,null],[1,null],[0,null],[4,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[2,null],[-1,null],[-1,null],[1,null],[12,["24","10","action:sieveSponIaJobs"]],[-1,[]],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[1,null],[-1,null],[2,["jobse0","jobal0","viewj0","savej0","8232301"]],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[3,null],[-1,null],[-1,null],[-1,null],[-1,null],[6,["AU"]],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[2,null],[-1,null],[1,null],[3,null],[3,3],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[4,["1","2","22","1","144","1","552","1","3648","1","4392","1"]],[-1,-1],[1,null],[1,null],[-1,null],[1,null],[1,null],[1,null],[1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[1,"1"],[4,0],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[1,null],[2,null],[-1,null],[1,null],[1,null],[1,null],[-1,null],[0,null],[1,null],[-1,null],[2,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,[]],[1,null],[0,null],[-1,null],[-1,null],[2,null],[1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,-1],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[3,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[3,null],[1,null],[1,null],[2,0.0],[1,null],[4,["notop","nobottom","newontop"]],[-1,null],[2,null],[1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[1,null],[1,null],[-1,null],[1,null],[-1,null],[-1,"-1"],[6,["Ad: Urgently Hiring"]],[0,null],[-1,null],[1,null],[1,null],[-1,null],[-1,null],[2,null],[-1,null],[1,null],[1,null],[-1,null],[-1,null],[0,null],[-1,null],[3,"aggsrf_v1,async"],[0,null],[1,null],[-1,null],[-1,null],[0,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[0,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[0,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[1,null],[-1,null],[-1,null],[-1,null],[-1,nu ...
#
#                 document.js.reset();
#                 jobSeenInit('1crciuptq108c002', [{
#                     'jobClassName': 'result',
#                     'scanIta': true,
#                     'containsSponsored': true,
#                     'context': ''
#                 }]);
#
#             if ( document.radius_update ) { document.radius_update.reset(); }
#
#
#             initJobsearchUnloadBeacon('1crciuptq108c002');
#             initApplyStartTimestamp();
#         }
#
#         initLogInitialUserInteraction('1crciuptq108c002', 'serp');
#
#         window.onload = onLoadHandler;
#   </script>
#   <link href="android-app://com.indeed.android.jobsearch/https/au.indeed.com/m/jobs?q=data+scientist&amp;l=Sydney+NSW" rel="alternate"/>
#   <title>
#    Data Scientist Jobs in Sydney NSW (with Salaries) | Indeed.com
#   </title>
#   <style type="text/css">
#    .btn,.sg-btn{display:inline-block;padding:9px 15px;border:1px solid #9a99ac;border-bottom-color:#a2a2a2;-webkit-border-radius:6px;-moz-border-radius:6px;-ms-border-radius:6px;-o-border-radius:6px;border-radius:6px;background-color:#D9D9E2;background-image:-moz-linear-gradient(top, #f8f8f9, #D9D9E2);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#f8f8f9), to(#D9D9E2));background-image:-webkit-linear-gradient(top, #f8f8f9, #D9D9E2);background-image:linear-gradient(to bottom, #f8f8f9, #D9D9E2);background-repeat:repeat-x;-webkit-box-shadow:0 1px 5px rgba(0,0,0,0.2);-moz-box-shadow:0 1px 5px rgba(0,0,0,0.2);-ms-box-shadow:0 1px 5px rgba(0,0,0,0.2);-o-box-shadow:0 1px 5px rgba(0,0,0,0.2);box-shadow:0 1px 5px rgba(0,0,0,0.2);color:#333;vertical-align:middle;text-align:center;text-decoration:none;text-shadow:0 1px #fff;font-weight:700;font-size:16px;font-family:"Helvetica Neue",Helvetica,Arial,"Lucida Grande",sans-serif;line-height:22px;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#fff8f8f9', endColorstr='#ffe6e6e6', GradientType=0);cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;-webkit-touch-callout:none;-webkit-highlight:none;-webkit-tap-highlight-color:transparent;text-overflow:ellipsis;white-space:nowrap;overflow:hidden}.btn.active,.btn.sg-active,.btn:active,.btn.disabled,.btn.sg-disabled,.btn[disabled],.sg-btn.active,.sg-btn.sg-active,.sg-btn:active,.sg-btn.disabled,.sg-btn.sg-disabled,.sg-btn[disabled]{outline:none;background-color:#f8f8f9;color:#333}.btn:focus,.sg-btn:focus{outline:0;box-shadow:0 0 1px 0 #1642bb;-webkit-transition:box-shadow 0.2s linear;-moz-transition:box-shadow 0.2s linear;transition:box-shadow 0.2s linear}.btn.active,.btn.sg-active,.btn:active,.sg-btn.active,.sg-btn.sg-active,.sg-btn:active{background-color:#f8f8f9;background-image:none;-webkit-box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05);-moz-box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05);box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05)}.btn.disabled,.btn.sg-disabled,.btn[disabled],.sg-btn.disabled,.sg-btn.sg-disabled,.sg-btn[disabled]{background-color:#f8f8f9;background-image:none;-webkit-box-shadow:none;-moz-box-shadow:none;box-shadow:none;opacity:.65;filter:alpha(opacity=65);cursor:default}.btn-primary,.sg-btn-primary{border-color:#1642bb;background-color:#5585f2;background-image:-moz-linear-gradient(top, #6598ff, #2e5ad7);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#6598ff), to(#2e5ad7));background-image:-webkit-linear-gradient(top, #6598ff, #2e5ad7);background-image:linear-gradient(to bottom, #6598ff, #2e5ad7);background-repeat:repeat-x;color:#F8F8F9;text-shadow:0 -1px #0f2299;-ms-filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f2299, Positive=true);filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f2299, Positive=true);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#ff6598fe', endColorstr='#ff3c69e0', GradientType=0);zoom:1}.btn-primary.active,.btn-primary.sg-active,.btn-primary:active,.btn-primary.disabled,.btn-primary.sg-disabled,.btn-primary[disabled],.sg-btn-primary.active,.sg-btn-primary.sg-active,.sg-btn-primary:active,.sg-btn-primary.disabled,.sg-btn-primary.sg-disabled,.sg-btn-primary[disabled]{background-color:#2e5ad7;color:#F8F8F9}.btn-primary:focus,.sg-btn-primary:focus{box-shadow:0 0 1px 0 #000}.btn-special,.sg-btn-special{border-color:#ba3200;background-color:#5585f2;background-image:-moz-linear-gradient(top, #f60, #f14200);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#f60), to(#f14200));background-image:-webkit-linear-gradient(top, #f60, #f14200);background-image:linear-gradient(to bottom, #f60, #f14200);background-repeat:repeat-x;color:#F8F8F9;text-shadow:0 -1px #000;-ms-filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f22 ...
#   </style>
#   <style>
#    body.janus{background-color:#f6f6f6}body.janus *,body.janus .jasxcustomfonttst-useAvenir *{font-family:"Helvetica Neue",Helvetica,Arial,sans-serif !important;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing:border-box}body.janus a,body.janus a:link{color:#2164f3}body.janus input::-webkit-contacts-auto-fill-button{visibility:hidden;display:none !important;pointer-events:none;position:absolute;right:0}body.janus .origin_site_link a{color:#085ff7}body.janus div#g_nav{border-bottom:2px solid #f6f6f6 !important;height:46px !important;margin-bottom:0}body.janus div#g_nav a{cursor:pointer;color:#4b4b4b !important;font-weight:400}body.janus div#g_nav#inboxLinkNavbar{font-weight:500 !important;font-size:12px !important;line-height:15.6px !important}body.janus div#g_nav .navBi a{font-size:12px;font-weight:500;position:relative;padding:12px 0;text-decoration:none}body.janus div#g_nav .navBi a:after{content:'';border-bottom:2px solid transparent;position:absolute;bottom:1px;left:0;right:0}body.janus div#g_nav .navBi a#userOptionsLabel{color:#2164f3 !important;font-size:12px;padding:12px 0}body.janus div#g_nav .navBi a:hover:after{border-color:#1497ff}body.janus div#g_nav .navBi a.selected{color:#000 !important;font-weight:700}body.janus div#g_nav .navBi a.selected:after{border-color:#2164f3}body.janus div#g_nav #userOptionsLabel{border-radius:15px 15px 0 0;border:2px solid transparent;margin-bottom:0 !important}body.janus div#g_nav #userOptionsLabel b{text-decoration:none}body.janus div#g_nav #userOptionsLabel.active{border-color:#f6f6f6;padding:9px 12px !important}body.janus div#g_nav #userOptions{border:2px solid #f6f6f6;border-radius:15px 0 15px 15px;box-shadow:2px 3px 8px 0 rgba(0,0,0,0.08);padding:4px 0;margin-top:-1px}body.janus div#g_nav #userOptions .userOptionGroupHeader,body.janus div#g_nav #userOptions .userOptionItem a,body.janus div#g_nav #userOptions .userNameRepeat{display:block;min-width:220px;padding:2px 16px}body.janus div#g_nav #userOptions .userOptionGroup{border-top:2px solid #f6f6f6}body.janus div#g_nav table{height:55px;margin-top:-8px}body.janus div#g_nav td{padding:0 !important}body.janus .inwrapBorder{border:0 !important}body.janus .inwrapBorder .inwrapBorderTop{background-color:transparent !important;background-image:none !important;border:0 !important}body.janus .inwrapBorder .input_submit{border-radius:100px !important;font-family:"Helvetica Neue",Helvetica,Arial,"Liberation Sans",Roboto,Noto,sans-serif;font-size:0.75rem;letter-spacing:0;font-weight:700;line-height:1.34;line-height:24px;padding:4px 1.5rem !important;background-color:#085ff7 !important;border:2px solid #085ff7 !important;color:#fff !important;font-weight:500;box-sizing:border-box}body.janus .inwrapBorder .input_submit:focus{box-shadow:0 0 0 2px #F1F3F6,0 0 0px 4px #085ff7 !important;outline:0 !important}body.janus .inwrapBorder .input_submit:hover{background-color:#1497ff !important;border-color:#1497ff !important}body.janus .inwrapBorder .input_submit:hover:focus{box-shadow:0 0 0 2px #F1F3F6,0 0 0px 4px #1497ff !important;outline:0 !important}body.janus .inwrapBorder .input_submit:disabled{color:#ccc !important;background-color:#fff !important;border-color:#fff !important}body.janus .inwrapBorder .input_submit.brandAdFollow,body.janus .inwrapBorder .input_submit.followButton{background-image:none !important}body.janus .inwrapBorder input.input_text{border:2px solid #ccc !important;box-sizing:border-box;background-color:#ececec}body.janus .inwrap{border:0 !important}body.janus #jobsearch .sl{color:#6f6f6f;margin-left:4px;padding-right:20px;font-size:0.75rem;line-height:1.67}body.janus #jobsearch td.npl{padding:0 !important}body.janus #jobsearch #what_label_top,body.janus #jobsearch #where_label_top{display:block}body.janus #jobsearch #what_label_bot,body.janus #jobsearch #where_label_bot,body.janus #jobsearch #what_label,body.janus #jobsearch #where_label{display:block;color:#6f6f6f;font-size:0.625rem;font-weig ...
# body.janus .related_searches_right-rail_title{padding:12px 16px !important;border-bottom:2px solid #f6f6f6;background-color:#fff;font-size:12px;color:#4b4b4b;font-weight:500}body.janus .related_searches_right-rail_list{background-color:#fff;border:0;color:#909090;font-size:12px;font-weight:400;line-height:1.5;padding:16px;padding:16px 16px 20px;margin:0}body.janus .related_searches_right-rail_list .related_searches_right-rail_list-item{list-style-type:none}body.janus .related_searches_right-rail_list .related_searches_right-rail_list-item_with-border{display:inline}body.janus .related_searches_right-rail_list .related_searches_right-rail_list-item_with-border:not(last-child):after{content:'-';margin-left:3px;margin-right:3px}body.janus #jobsearch{padding-left:24px !important}body.janus #jobsearch .label,body.janus #jobsearch .label label,body.janus .lav .jsf .label,body.janus .result .location,body.janus #resultsCol .more_actions ul li .mat{color:#909090}body.janus .footer{height:50px;border-top-width:2px;padding:9px 0}body.janus #footerMainLinks{margin:10px 0 -5px}body.janus #resultsBody .indeed-apply-button{border-radius:100px !important;font-family:"Helvetica Neue",Helvetica,Arial,"Liberation Sans",Roboto,Noto,sans-serif;font-size:0.875rem;letter-spacing:0;font-weight:700;line-height:1.43;line-height:24px;padding:0.5rem 1.5rem !important;background-color:#ff5a1f !important;border:2px solid #ff5a1f !important;color:#fff !important;font-size:18.66px;background-image:none;padding:0;height:auto !important}body.janus #resultsBody .indeed-apply-button:focus{box-shadow:0 0 0 2px #F1F3F6,0 0 0px 4px #085ff7 !important;outline:0 !important}body.janus #resultsBody .indeed-apply-button:focus{box-shadow:0 0 0 2px #F1F3F6,0 0 0px 4px #ff6c40 !important;outline:0 !important}body.janus #resultsBody .indeed-apply-button:hover{background-color:#ff6c40 !important;border-color:#ff6c40 !important}body.janus #resultsBody .indeed-apply-button:hover:focus{box-shadow:0 0 0 2px #F1F3F6,0 0 0px 4px #ff6c40 !important;outline:0 !important}body.janus #resultsBody .indeed-apply-button:disabled{color:#ccc !important;background-color:#fff !important;border-color:#fff !important}body.janus #resultsBody .indeed-apply-button .indeed-apply-button-inner{background:#fff;background-image:none !important;border:2px solid transparent;border-radius:100px !important;box-shadow:none;box-sizing:border-box;color:#085ff7;max-width:100% !important;text-shadow:none !important}body.janus #resultsBody .indeed-apply-button .indeed-apply-button-inner:focus{box-shadow:0 0 0 2px #F1F3F6,0 0 0px 4px #085ff7 !important;outline:0 !important}body.janus #resultsBody .indeed-apply-button:hover{border-color:#1497ff;background-color:none;background-image:none}body.janus #resultsBody .indeed-apply-button:hover .indeed-apply-button-inner{background-image:none}body.janus #resultsBody .indeed-apply-button:hover .indeed-apply-button-label{color:#1497ff}body.janus #resultsBody .indeed-apply-button .indeed-apply-button-label{color:#085ff7;line-height:25px;padding:3px 14px;border-radius:0}body.janus #alertemail,body.janus #talertemail,body.janus #balertemail{background:#fff !important;border:2px solid #ccc !important;border-radius:4px !important;color:#4b4b4b !important;font-family:"Helvetica Neue",Helvetica,Arial,"Liberation Sans",Roboto,Noto,sans-serif;font-size:0.75rem;letter-spacing:0;font-weight:400;line-height:1.34;min-height:36px !important;padding:0.5rem 1rem !important}body.janus #alertemail:focus,body.janus #alertemail:active,body.janus #talertemail:focus,body.janus #talertemail:active,body.janus #balertemail:focus,body.janus #balertemail:active{border-color:#1497ff !important;outline:0 !important}body.janus #resultsCol #balertemail{margin-right:-5px}body.janus #resultsCol #balertsubmit{position:relative;top:0 !important;left:-2px}body.janus #balertsubmit,body.janus #talertsubmit,body.janus #alertsubmit{background-color:#fff !important;background-image:none !important;border:2px sol ...
#   </style>
#   <style>
#    body.janus #what_acdiv.acd{border:0 !important;border-color:inherit !important}body.janus .z-index-override{z-index:101 !important}body.janus #what_acdiv.acd,body.janus #acdiv.acd,body.janus #acdiv_where_alert.acd{border:0 !important;width:100% !important;z-index:101}body.janus #what_acdiv.acd ul,body.janus #acdiv.acd ul,body.janus #acdiv_where_alert.acd ul{border:2px solid #1497ff !important;border-radius:15px;box-shadow:2px 3px 8px 0 rgba(0,0,0,0.08);overflow:hidden}body.janus #what_acdiv.acd li.ac-active:hover,body.janus #what_acdiv.acd li.ac-active:active,body.janus #acdiv.acd li.ac-active:hover,body.janus #acdiv.acd li.ac-active:active,body.janus #acdiv_where_alert.acd li.ac-active:hover,body.janus #acdiv_where_alert.acd li.ac-active:active{color:#4b4b4b !important}body.janus .ac-active{color:#4b4b4b !important;background-color:#ececec !important}body.janus .ac-row{font-size:.875rem;padding:0.5rem 1rem}body.janus .ac-row .bold{color:#000}
#   </style>
#  </head>
#  <body class="ltr jasxcustomfonttst-inactive janus" data-tn-application="jasx" data-tn-olth="41be357fa1c7dc26c5ee98836f8950b3" data-tn-originlogid="1crciuptq108c002" data-tn-originlogtype="jobsearch">
#   <div id="accessibilityBanner">
#    <span id="accessibilityText">
#     Skip to
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#jobPostingsAnchor" id="skipToJobs">
#      Job Postings
#     </a>
#     ,
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#what" id="skipToSearch">
#      Search
#     </a>
#    </span>
#    <a id="accessibilityClose">
#     Close
#    </a>
#   </div>
#   <script type="text/javascript">
#    createTabBar('1crciuptq108c002');
#   </script>
#   <script>
#    var vjsExhibitionModel = new indeed.vjsExhibition('auxCol');
#         var vjsStable = true;
#         //For SERP jobs, the scope of these job are document
#         var viewJobOnSerp = new indeed.vjs('1crciuptq108c002', 'vjs', document, vjsExhibitionModel);
#         var vjk = viewJobOnSerp.getVJK();
#         var vjFrom = viewJobOnSerp.getFrom();
#         var vjTk = viewJobOnSerp.getTk();
#         var vjUrl = viewJobOnSerp.vjUrl(vjk, vjFrom, vjTk);
#         var showVjOnSerp = vjsStable;
#         var zrp = false;
#         if ((zrp || !showVjOnSerp || window.innerWidth < 1200) && vjUrl) {
#             window.location.replace(vjUrl);
#         } else if (showVjOnSerp) {
#             initializeTwoPaneAndRecList();
#         }
#         function initializeTwoPaneAndRecList() {
#             var jobKeysWithInfo = {};
#
#             jobKeysWithInfo['8db5c8216d584095'] = true;
#
#             jobKeysWithInfo['dcef5391be31a8f8'] = true;
#
#             jobKeysWithInfo['e6061c4bcd809346'] = true;
#
#             jobKeysWithInfo['ce833063e5ad30c4'] = true;
#
#             jobKeysWithInfo['83053c575a2682db'] = true;
#
#             jobKeysWithInfo['28cf2c12c2518119'] = true;
#
#             jobKeysWithInfo['d4fd789fc476bbea'] = true;
#
#             jobKeysWithInfo['2a0deccc431450fc'] = true;
#
#             jobKeysWithInfo['5b131998aec952e9'] = true;
#
#             jobKeysWithInfo['a091f7372614f6d8'] = true;
#
#             jobKeysWithInfo['2bcf9e3e45015033'] = true;
#
#             jobKeysWithInfo['2ea86bdbee4ff63e'] = true;
#
#             jobKeysWithInfo['38c4f3521de26e0b'] = true;
#
#             jobKeysWithInfo['6095d92795d0cf22'] = true;
#
#             jobKeysWithInfo['fdba7083fc88d4c2'] = true;
#
#             if (vjk && !jobKeysWithInfo.hasOwnProperty(vjk)) {
#                 jobKeysWithInfo[vjk] = true;
#             }
#             viewJobOnSerp.preloadDescs(jobKeysWithInfo);
#             window.bindAndRender = function () {
#                 if (showVjOnSerp) {
#                     viewJobOnSerp.bindJobKeys(jobKeysWithInfo);
#                     if (vjUrl) {
#                         var vjFrom = viewJobOnSerp.getFrom();
#                         var vjTk = viewJobOnSerp.getTk();
#                         viewJobOnSerp.renderOnJobKey(vjk, vjFrom, vjTk, undefined, function () {
#                             window.location.replace(vjUrl);
#                         }, function() {
#
#                             restore('savedjobs');
#
#                         });
#                     }
#                 }
#             };
#             var showRecList = false;
#             if (showRecList) {
#                 var j2jRecOnSerp = new indeed.rjs('1crciuptq108c002', 'j2jrecvjs', '1crciupso108c000', 'AU', 'en', false, vjsExhibitionModel);
#                 window.bindKeyAndRenderRecommended = function () {
#                     j2jRecOnSerp.bindJobKeys(jobKeysWithInfo);
#                 };
#             }
#         }
#   </script>
#   <style type="text/css">
#    body { margin-top: 0; margin-left: 0; margin-right: 0; padding-top: 0; padding-right: 0; padding-left: 0; }
#
#     #g_nav { border-bottom:1px solid #ccc; margin-bottom:9px; }
#
#     #g_nav a,
#     #g_nav a:visited { color: #00c; }
#
#     .navBi { display: -moz-inline-box; display: inline-block; padding: 9px 12px; margin: 0; list-style-type: none; }
#   </style>
#   <div class="left" data-tn-section="globalNav" id="g_nav" role="navigation">
#    <table cellpadding="0" cellspacing="0" width="100%">
#     <tr>
#      <td nowrap="">
#       <style type="text/css">
#        #p_nav a.selected { font-weight: bold; text-decoration:none; color: #000 !important; }
#       </style>
#       <div id="p_nav">
#        <span class="navBi">
#         <a class="selected" href="/" id="jobsLink" title="Jobs">
#          Find Jobs
#         </a>
#        </span>
#        <span class="navBi">
#         <a href="/companies" onmousedown="this.href = appendParamsOnce(this.href, '?from=headercmplink&amp;attributionid=jobsearch')">
#          Company Reviews
#         </a>
#        </span>
#        <span class="navBi">
#         <a href="/salaries" onmousedown="this.href = appendParamsOnce(this.href, '?from=headercmplink&amp;attributionid=jobsearch')">
#          Find Salaries
#         </a>
#        </span>
#        <span class="navBi">
#         <a href="http://www.indeed.com/resumes?co=AU&amp;sp=0&amp;isid=find-resumes-AU&amp;ikw=SERPtop&amp;hl=en" id="rezLink" rel="nofollow">
#          Find Resumes
#         </a>
#        </span>
#        <span class="navBi">
#         <a href="/hire?hl=en&amp;cc=AU" id="empLink" onclick="if ( this.href.match('&amp;isid=employerlink-AU&amp;ikw=SERPtop') == null ) { this.href += '&amp;isid=employerlink-AU&amp;ikw=SERPtop' };">
#          Employers / Post Job
#         </a>
#        </span>
#       </div>
#      </td>
#      <td align="right" nowrap="">
#       <style type="text/css">
#        #navpromo a,
#     #navpromo a:visited {
#         color: #f60;
#     }
#
#
#     #u_nav .login_unconfirmed,
#     #u_nav .login_unconfirmed a,
#     #u_nav .login_unconfirmed a:visited {
#         color: #c00
#     }
#
#     #u_nav .resume_pending,
#     #u_nav .resume_pending a,
#     #u_nav .resume_pending a:visited {
#         color: #c00
#     }
#
#     #userOptionsLabel {
#         position: relative;
#         z-index: 5;
#     }
#
#     #userOptionsLabel b {
#         cursor: pointer;
#         text-decoration: underline;
#         position: relative;
#         z-index: 5;
#     }
#
#     #userOptionsLabel:active {
#         outline: none;
#     }
#
#     #userOptionsLabel.active {
#         padding: 9px 11px;
#         margin-bottom: -1px;
#         _margin-bottom: 0px;
#         border: 1px solid #ccc;
#         border-top: 0;
#     }
#
#     #userOptionsLabel.active .arrowStub {
#         border-width: 0 3px 3px;
#         _border-width: 0px 3px 4px;
#         border-color: transparent;
#         border-bottom-color: #666;
#         top: -2px;
#         border-style: dashed dashed solid;
#     }
#
#     #userOptionsLabel.active .halfPxlFix {
#         background: #fff;
#         bottom: -3px;
#         height: 6px;
#         left: 0;
#         position: absolute;
#         right: 0;
#         border: 1px solid #fff;
#     }
#
#     .arrowStub {
#         position: relative;
#         border-style: solid dashed dashed;
#         border-color: transparent;
#         border-top-color: #666;
#         display: -moz-inline-box;
#         display: inline-block;
#         font-size: 0;
#         height: 0;
#         line-height: 0;
#         width: 0;
#     left: 4px;
#         border-top-width: 3px;
#         border-bottom-width: 0;
#         border-right-width: 3px;
#         padding-top: 1px;
#         top: -1px;
#     }
#
#     #userOptions {
#         z-index: 2;
#         visibility: hidden;
#         position: absolute;
#     right: 0;
#         x_right: -1px;
#         top: 100%;
#         padding: 9px 15px;
#         border: 1px solid #ccc;
#         background: #fff;
#         min-width: 150px;
#         _width: 150px;
#         text-align: left;
#     }
#
#     #userOptions.open {
#         visibility: visible;
#     }
#
#     .userOptionItem {
#         margin: 6px 0;
#     }
#
#     .userOptionItem a {
#         white-space: nowrap;
#     }
#
#     .userOptionGroup {
#         border-top: 1px solid #e8e8e8;
#         margin-top: 12px;
#     }
#
#     .userNameRepeat {
#         color: #a8a8a8;
#         padding-right: 48px;
#         font-weight: bold;
#     }
#
#     .userOptionGroupHeader {
#         font-weight: bold;
#         margin: 6px 0;
#     }
#       </style>
#       <div id="u_nav">
#        <script>
#         function regExpEscape(s) {
#     return String(s).replace(/([-()\[\]{}+?*.$\^|,:#<!\\])/g, '\\$1').
#             replace(/\x08/g, '\\x08');
# }
#
#
# function appendParamsOnce(url, params) {
#   var useParams = params.replace(/^(\?|\&)/, '');
#   var anchorRegExp = new RegExp(/#.*$/);
#   var urlAnchorMatch = url.match(anchorRegExp);
#
#   var anchor = urlAnchorMatch == null ? '' : urlAnchorMatch;
#   url = url.replace(anchorRegExp, '');
#
#   if (url.match(new RegExp('[\\?|\\&]' + regExpEscape(useParams))) == null) {
#     url += (url.indexOf('?') > 0 ? '&' : '?') + useParams;
#   }
#   url += anchor;
#
#   return url;
# }
#        </script>
#        <div id="user_actions">
#         <span class="navBi resumeCTAWhiteOutline ">
#          <span class="resume-promo" id="navpromo">
#           <a href="/promo/resume" onclick="window.location=this.href + '?from=serpnav&amp;subfrom=rezprmstd&amp;trk.origin=jobsearch&amp;trk.variant=rezprmstd&amp;trk.pos=nav&amp;trk.tk=1crciuptq108c002'; return false;">
#            Upload your resume
#           </a>
#          </span>
#         </span>
#         <span class="navBi">
#          <a href="https://au.indeed.com/account/login?dest=%2Fjobs%3Fq%3Ddata%2Bscientist%26l%3DSydney%2BNSW" id="userOptionsLabel" rel="nofollow">
#           Sign in
#          </a>
#         </span>
#        </div>
#       </div>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <style type="text/css">
#    .indeedLogo {
#         margin: 8px 0 0 9px;
#         border: 0;
#         width: 166px;
#         height: 64px;
#     }
#
#             .indeedLogo {
#                 background: url("data:image/svg+xml;charset=utf8,%3Csvg xmlns='http://www.w3.org/2000/svg' xmlns:xlink='http://www.w3.org/1999/xlink' viewBox='0 0 320 80'%3E%3Cpath d='M287.31 13.4a5.24 5.24 0 0 0-4.22-1.76 5 5 0 0 0-4.22 1.92 9 9 0 0 0-1.49 5.59V37a24.49 24.49 0 0 0-7-5.52 16.88 16.88 0 0 0-5.2-1.56 25.92 25.92 0 0 0-3.6-.24A18.43 18.43 0 0 0 247.06 36c-3.67 4.23-5.51 10.09-5.51 17.65A33.74 33.74 0 0 0 243 63.6a24 24 0 0 0 4.06 8 19.15 19.15 0 0 0 6.41 5.24 17.87 17.87 0 0 0 8 1.84 19.14 19.14 0 0 0 3.75-.35 14.73 14.73 0 0 0 2.27-.55 19.32 19.32 0 0 0 5.12-2.66 30.13 30.13 0 0 0 4.81-4.54v1.17a7.52 7.52 0 0 0 1.6 5.13 5.66 5.66 0 0 0 8.21.08 7.48 7.48 0 0 0 1.8-5.17V18.48a7.76 7.76 0 0 0-1.72-5.08zm-12.15 49.22a11.56 11.56 0 0 1-4.18 5 10.7 10.7 0 0 1-5.78 1.64 10.45 10.45 0 0 1-5.78-1.72 11.84 11.84 0 0 1-4.18-5.16 20.67 20.67 0 0 1-1.52-8.37 20.86 20.86 0 0 1 1.45-8.14 12 12 0 0 1 4-5.4 9.68 9.68 0 0 1 5.94-1.88h.12a9.93 9.93 0 0 1 5.74 1.84 12.56 12.56 0 0 1 4.22 5.28 19.89 19.89 0 0 1 1.56 8.29 20.36 20.36 0 0 1-1.59 8.62zm-37.9.51a4.38 4.38 0 0 0-3-1 4 4 0 0 0-2.62.78c-1.52 1.41-2.74 2.54-3.67 3.36a33.69 33.69 0 0 1-3.13 2.31 12.3 12.3 0 0 1-3.44 1.57 14 14 0 0 1-3.95.51 6.6 6.6 0 0 1-.9 0 10.72 10.72 0 0 1-5-1.57 11.55 11.55 0 0 1-4.3-4.66A17.22 17.22 0 0 1 205.6 57h23.54c3.17 0 5.65-.34 7.37-1.2s2.62-2.9 2.62-5.91a20.41 20.41 0 0 0-2.54-9.66 19.64 19.64 0 0 0-7.59-7.74 23.28 23.28 0 0 0-12.12-3h-.35a27.4 27.4 0 0 0-9.53 1.75 21.07 21.07 0 0 0-7.54 5 22.48 22.48 0 0 0-4.61 7.86 30.26 30.26 0 0 0-1.6 9.94c0 7.59 2.15 13.54 6.45 18 4.06 4.19 9.69 6.38 16.84 6.61h1.25a27.65 27.65 0 0 0 9-1.33 22.39 22.39 0 0 0 6.48-3.32 16 16 0 0 0 3.87-4.23 7.8 7.8 0 0 0 1.29-3.8 3.58 3.58 0 0 0-1.17-2.84zm-28.14-22.4a9.58 9.58 0 0 1 7.39-3.09 9.94 9.94 0 0 1 7.58 3.05c1.91 2 3 5.25 3.32 9.4H205.6c.4-4.09 1.57-7.29 3.52-9.36zM189 63.13a4.38 4.38 0 0 0-3-1 4 4 0 0 0-2.62.78c-1.52 1.41-2.74 2.54-3.67 3.36a33.69 33.69 0 0 1-3.13 2.31 12.3 12.3 0 0 1-3.44 1.57 14 14 0 0 1-3.95.51 6.6 6.6 0 0 1-.9 0 10.72 10.72 0 0 1-5-1.57 11.55 11.55 0 0 1-4.3-4.66 17.22 17.22 0 0 1-1.64-7.43h23.54c3.17 0 5.65-.34 7.37-1.2s2.62-2.9 2.62-5.91a20.41 20.41 0 0 0-2.54-9.66 19.64 19.64 0 0 0-7.58-7.71 23.28 23.28 0 0 0-12.12-3h-.35a27.4 27.4 0 0 0-9.54 1.72 21.07 21.07 0 0 0-7.54 5 22.48 22.48 0 0 0-4.61 7.86 30.26 30.26 0 0 0-1.6 9.94c0 7.59 2.15 13.54 6.45 18 4.06 4.19 9.69 6.38 16.84 6.61h1.25a27.65 27.65 0 0 0 9-1.33A22.39 22.39 0 0 0 185 74a16 16 0 0 0 3.87-4.23 7.8 7.8 0 0 0 1.29-3.8 3.58 3.58 0 0 0-1.16-2.84zm-28.14-22.4a9.58 9.58 0 0 1 7.39-3.09 9.94 9.94 0 0 1 7.58 3.05c1.91 2 3 5.25 3.32 9.4h-21.8c.39-4.09 1.56-7.29 3.52-9.36zm-21.65-27.17A5.26 5.26 0 0 0 135 11.8a5 5 0 0 0-4.22 1.92c-1.31 1.52-1.65 3.24-1.65 5.7V37.2a23.57 23.57 0 0 0-6.62-5.57 17.21 17.21 0 0 0-5.2-1.56 25.92 25.92 0 0 0-3.6-.24 18.38 18.38 0 0 0-14.54 6.34c-3.63 4.23-5.47 10.1-5.47 17.65a35.11 35.11 0 0 0 1.37 9.94 24.13 24.13 0 0 0 4.1 8 19.15 19.15 0 0 0 6.41 5.24 17.87 17.87 0 0 0 8 1.84 19.72 19.72 0 0 0 3.75-.35 14.67 14.67 0 0 0 2.27-.55 19.32 19.32 0 0 0 5.12-2.66 31.93 31.93 0 0 0 4.81-4.54v1.17a7.52 7.52 0 0 0 1.6 5.13 5.62 5.62 0 0 0 8.17.08 7.53 7.53 0 0 0 1.56-5.2V18.68a7.87 7.87 0 0 0-1.65-5.12zm-11.9 49.22a11.37 11.37 0 0 1-4.22 5 10.57 10.57 0 0 1-5.74 1.64 10.44 10.44 0 0 1-5.78-1.72 11.58 11.58 0 0 1-4.18-5.16 20.68 20.68 0 0 1-1.52-8.37 21.64 21.64 0 0 1 1.41-8.14 12.08 12.08 0 0 1 4.06-5.4 9.57 9.57 0 0 1 5.9-1.88h.16a9.72 9.72 0 0 1 5.6 1.88 12.35 12.35 0 0 1 4.26 5.28 20.52 20.52 0 0 1 1.56 8.29 21 21 0 0 1-1.51 8.58zM26 71.27v-28.8c.82.08 1.6.12 2.42.12A20.27 20.27 0 0 0 39 39.65v31.62c0 2.7-.49 4.7-1.71 6a6.16 6.16 0 0 1-4.77 2 6 6 0 0 1-4.69-2c-1.21-1.33-1.84-3.33-1.84-6zm-.12-69C34-.69 43.28-.53 50.23 5.5a11.79 11.79 0 0 1 3.36 4.5c.7 2.27-2.46-.23-2.89-.55a30.92 30.92 0 0 0-7.07-3.6C29.95 1.66 17 9.29 9 21.15A64.11 64.11 0 0 0 1.61 38a9.59 9.59 0 0 1-.7 2.11c-.35.67-.16-1.8-.16-1.88a52 52 0 0 1 1.41-7.36C5.87 17.94 14.08 7.18 25.88 2.25zm10. ...
#                 margin-left: 16px;
#                 height: 40px;
#             }
#
# #branding img { border: 0; }
# #jobsearch { margin: 0 }
# .inwrap { border-right: 1px solid #e8e8e8;border-bottom: 1px solid #e8e8e8;display:inline-block; }
# .inwrap input { box-sizing: border-box; margin:0; height: 30px; font-family:Arial,sans-serif;border:1px solid #ccc; border-bottom-color:#aaa;border-right-color:#aaa; -webkit-border-radius: 0; -webkit-appearance: none; }
# .inwrap .input_text { font-size:18px;padding:3px 6px;_margin: -1px 0; }
# .inwrap .input_submit {color:#614041;font-size:15px;height:30px;background: #e8e8e8; padding:3px 9px;cursor:pointer;_padding:3px;}
# .inwrap .input_submit:active { background: #ccc; }
# .lnav  {width:100%;line-height:1;;font-size:10pt;}
# .jsf .label {font-size:12px; line-height:1.2;padding-top:0;color:#aaa;font-weight:normal;white-space:nowrap;padding-right:1.5em}
# .jsf .label label {font-weight:normal}
# .jsf .sl { font-size: 11px; color: #77c; white-space: nowrap; }
# .npb { padding-bottom: 0; color: #f60; font-weight:bold; }
# .npl { padding-left: 0 }
# iframe { display:block; }
#
# .acd { position:absolute; width:100%; z-index: 1; }
# #acdiv { width: 364px; }
# #what_acdiv { width: 662px; }
# .acd ul { border: 1px solid #333; background: #fff; padding: 0; margin: 3px 0 0 0; }
# .acd li { list-style-type: none; font-size: 18px; padding:1px 6px; cursor:pointer; }
# .acd li.ac-active { background:#36c; color:#fff; }
#
# #jobalerts .ws_label,
# #jobalerts .member { z-index: 1; }
# #acr td { padding-top:0; padding-bottom:0; }
# #acr td .h { display:none; }
#
# #what { width: 280px; }
# #where { width: 260px; }
# .inwrapBorder{border:1px solid #1C4ED9;border-top-color:#2F62F1;border-bottom-color:#133FBB;display:inline-block;width:auto;}
# .inwrapBorderTop{border-top:1px solid #69F;display:inline-block;background-color:#3163F2;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#3163F2',endColorstr='#2B57D5');background:-webkit-gradient(linear,left top,left bottom,from(#3163F2),to(#2B57D5));background:-moz-linear-gradient(top,#3163F2,#2B57D5);background:linear-gradient(top,#3163F2,#2B57D5);}
# .inwrapBorder .input_submit{background: transparent;border:0;color:#fff;font-family:Arial;font-size:15px;margin:0;padding:4px 9px;cursor:pointer;_padding:3px;}
# .inwrapBorder a.input_submit{text-decoration: none; display: block;}
#
# .inwrapBorder:hover{border-color:#235af6;border-top-color:#4072ff;border-bottom-color:#1e4fd9;}
# .inwrapBorderTop:hover{border-top-color:#7ba7ff;background-color:#4273ff;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#4273ff',endColorstr='#3364f1');background:-webkit-gradient(linear,left top,left bottom,from(#4273ff),to(#3364f1));background:-moz-linear-gradient(top,#4273ff,#3364f1);background:linear-gradient(top,#4273ff,#3364f1);}
#
# .inwrapBorder:active{border-color:#536db7;border-top-color:#4b69c1;border-bottom-color:#3753a6;}
# .inwrapBorder:active .inwrapBorderTop{border-top-color:#6c82c1;background-color:#4b69c1;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#4b69c1',endColorstr='#3753a6');background:-webkit-gradient(linear,left top,left bottom,from(#4b69c1),to(#3753a6));background:-moz-linear-gradient(top,#4b69c1,#3753a6);background:linear-gradient(top,#4b69c1,#3753a6);}
#
# .roundedCorner {
#     display: inline-block;
#     zoom: 1; /* zoom and *display = ie7 hack for display:inline-block */
#     *display: inline;
#     vertical-align: baseline;
#     margin: 0 2px;
#     outline: none;
#     cursor: pointer;
#     text-align: center;
#     text-decoration: none;
#     font: 15px/100% Arial, Helvetica, sans-serif;
#     padding: .5em 2em .55em;
#     text-shadow: 0 1px 1px rgba(0,0,0,.3);
#     -webkit-border-radius: .5em;
#     -moz-border-radius: .5em;
#     border-radius: .5em;
#     -webkit-box-shadow: 0 1px 2px rgba(0,0,0,.2);
#     -moz-box-shadow: 0 1px 2px rgba(0,0,0,.2);
#     box-shadow: 0 1px 2px rgba(0,0,0,.2);
# }
# .roundedCorner:hover {
#     text-decoration: none;
# }
# .roundedCorner:active {
#     position: relative;
#     top: 1px;
# }
#
# .bigrounded {
#     -webkit-border-radius: 2em;
#     -moz-border-radius: 2em;
#     border-radius: 2em;
# }
# .medium {
#     font-size: 12px;
#     padding: .4em 1.5em .42em;
# }
# .small {
#     font-size: 11px;
#     padding: .2em 1em .275em;
# }
#
# .indeedblue {
#     color: #d9eef7;
#     border: solid 1px #1C4ED9;
#     background: #3163F2;
#     background: -webkit-gradient(linear, left top, left bottom, from(#2F62F1), to(#133FBB));
#     background: -moz-linear-gradient(top,  #2F62F1,  #133FBB);
#     filter:  progid:DXImageTransform.Microsoft.gradient(startColorstr='#2F62F1', endColorstr='#133FBB');
# }
# .indeedblue:hover, .indeedblue:focus {
#     background: #235af6;
#     background: -webkit-gradient(linear, left top, left bottom, from(#4072ff), to(#1e4fd9));
#     background: -moz-linear-gradient(top,  #4072ff,  #1e4fd9);
#     filter:  progid:DXImageTransform.Microsoft.gradient(startColorstr='#4072ff', endColorstr='#1e4fd9');
# }
# .indeedblue:active {
#     color: #d9eef7;
#     background: -webkit-gradient(linear, left top, left bottom, from(#4b69c1), to(#3753a6));
#     background: -moz-linear-gradient(top,  #4b69c1,  #3753a6);
#     filter:  progid:DXImageTransform.Microsoft.gradient(startColorstr='#4b69c1', endColorstr='#3753a6');
# }
#   </style>
#   <span id="hidden_colon" style="display:none">
#    :
#   </span>
#   <table border="0" cellpadding="0" cellspacing="0" role="banner">
#    <tr>
#     <td width="1125">
#      <table cellpadding="0" cellspacing="0" class="lnav">
#       <tr>
#        <td id="branding-td">
# ...
#           </div>
#          </div>
#         </div>
#         <div id="univsrch-salary-v3">
#          <div id="univsrch-salary-info">
#           <div id="univsrch-salary-title">
#            Data Scientist salaries in Sydney, NSW
#           </div>
#           <div id="univsrch-salary-eval">
#            <div class="v3" id="univsrch-salary-rates">
#             <p class="v3" id="univsrch-salary-currentsalary">
#              <b>
#               $115,842
#              </b>
#              per year
#              <img id="univsrch-salary-stats-logo" src="/images/univsrch/icon_question_mark_grey.png" style="width:15px;"/>
#             </p>
#             <div class="salary-legal-disclaimer-container-group" id="salary-legal-disclaimer-container-distribution">
#              <div class="salary-legal-disclaimer-modal">
#               <div class="salary-legal-disclaimer-modal-close">
#               </div>
#               <div class="salary-legal-disclaimer-content">
#                <div class="salary-legal-disclaimer-title">
#                 Indeed Salary Estimate
#                </div>
#                <p>
#                 Please note that all salary figures are approximations based upon third party submissions to Indeed. These figures are given to the Indeed users for the purpose of generalized comparison only. Minimum wage may differ by jurisdiction and you should consult the employer for actual salary figures.
#                </p>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="v3" id="univsrch-salary-stats">
#             <p class="v3" id="univsrch-salary-stats-para">
#              Based on 152 salaries
#             </p>
#            </div>
#            <div id="univsrch-sal-distribution">
#             <ul>
#              <li style="height:65.86370461623767%; width:9.2%; left:0.0%;">
#              </li>
#              <li style="height:81.73270216593203%; width:9.2%; left:10.088999999999999%;">
#              </li>
#              <li style="height:89.85094981716067%; width:9.2%; left:20.177999999999997%;">
#              </li>
#              <li class="univsrch-sal-highlight" style="height:90.0%; width:9.2%; left:30.266999999999996%;">
#              </li>
#              <li style="height:83.8454215192752%; width:9.2%; left:40.355999999999995%;">
#              </li>
#              <li style="height:73.77173701845015%; width:9.2%; left:50.44499999999999%;">
#              </li>
#              <li style="height:62.01982574860148%; width:9.2%; left:60.53399999999999%;">
#              </li>
#              <li style="height:50.26919180592581%; width:9.2%; left:70.62299999999999%;">
#              </li>
#              <li style="height:39.55991722860872%; width:9.2%; left:80.71199999999999%;">
#              </li>
#              <li style="height:30.395307357110056%; width:9.2%; left:90.80099999999999%;">
#              </li>
#             </ul>
#             <div class="univsrch-sal-min univsrch-sal-caption float-left">
#              <div class="float-left" style="width: 13.07px;">
#              </div>
#              <span>
#               Min
#               <br/>
#               $41,000
#              </span>
#             </div>
#             <div class="univsrch-sal-max univsrch-sal-caption float-right">
#              <div class="float-right" style="width: 13.07px;">
#              </div>
#              <span>
#               Max
#               <br/>
#               $228,000
#              </span>
#             </div>
#            </div>
#            <div id="univsrch-salary-link">
#             <a href="/salaries/Data-Scientist-Salaries,-Sydney-NSW" onmousedown="this.href = appendParamsOnce(this.href, 'from=serpsalaryblock');" title="Data Scientist salaries by company in Sydney, NSW">
#              Data Scientist salaries by company in Sydney, NSW
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#         <script type="text/javascript">
#          usBindSalaryWidgetLoggingNew();
#         </script>
#         <script id="jaFloatScript" type="text/javascript">
#          initFloatingBoxes("#jobalertswrapper, #related-searches.related_searches_sticky");
#         </script>
#        </td>
#       </tr>
#      </table>
#      <script type="text/javascript">
#       function onClickResumePopoverPromo(uploadLink) {
#             var setYearExpiration = true;
#             var resumePopover = new ResumePopover('1crciuptq108c002', '1crciupso108c000', setYearExpiration);
#             resumePopover.onClickPromo(uploadLink);
#             return true;
#         }
#      </script>
#      <div class="resume-popover" id="resume-popover-background">
#      </div>
#      <div class="resume-popover" id="resume-popover-div">
#       <div id="resume-popover-x">
#        <button aria-label="close" id="resume-popover-close-button">
#         <span>
#          ×
#         </span>
#        </button>
#       </div>
#       <div id="postJobClickCta">
#        <div class="postJobClickCta_title">
#         Let Employers Find You
#        </div>
#        <div class="postJobClickCta_body">
#         Every day, thousands of employers search Indeed.com for candidates like you.
#        </div>
#        <span dir="ltr">
#         <a class="icl-Button icl-Button--primary icl-Button--lg cta_button blue" href="/promo/resume?from=resumePostJobClickCTA&amp;trk.origin=jobsearch" onclick="return onClickResumePopoverPromo('/promo/resume?from=resumePostJobClickCTA&amp;trk.origin=jobsearch');" target="_blank">
#          Upload Your Resume
#         </a>
#        </span>
#       </div>
#      </div>
#      <link href="/s/fb0bd3a/resumepopover.css" rel="stylesheet" type="text/css"/>
#      <script type="text/javascript">
#       window['resumePopoverShowValue'] = '1';
#      </script>
#      <script>
#       var focusHandlers = [];
# var linkHighlighter = new LinkHighlighter();
# focusHandlers.push(googBind(linkHighlighter.fadeToOriginalColor, linkHighlighter));
# var lostFocusHandlers = [];
# lostFocusHandlers.push(googBind(linkHighlighter.clickedAway, linkHighlighter, "#551a8b"));
#      </script>
#      <script>
#       if (!showVjOnSerp) {
#             var didYouApplyPrompt = new DidYouApplyPrompt('1crciuptq108c002', 60, 'serp',
#                 false);
#             focusHandlers.push(googBind(didYouApplyPrompt.returnedToPage, didYouApplyPrompt));
#             lostFocusHandlers.push(googBind(didYouApplyPrompt.leftPage, didYouApplyPrompt));
#             didYouApplyPrompt.dyaChangeFromCookie();
#         }
#      </script>
#      <script>
#       var clickTime = new ClickTime(window.tk, 'serp', 'jobtitle', focusHandlers, lostFocusHandlers);
#      </script>
#      <script type="text/javascript">
#       vjsExhibitionModel.initialize();
#         if (typeof bindAndRender !== 'undefined' && typeof bindAndRender === 'function') {
#             bindAndRender.apply();
#
#         }
#         if (typeof bindKeyAndRenderRecommended !== 'undefined' && typeof bindKeyAndRenderRecommended === 'function') {
#             bindKeyAndRenderRecommended.apply();
#         }
#      </script>
#      <script>
#       usBindRightRailLogging();
#      </script>
#      <script>
#       window['recaptchaSitekeyV2'] = "6Lc1uUEUAAAAAPHQRK9uCuJsLbJbUpwmnx5SARHu";
#         window['recaptchaSitekeyInvisible'] = "6Lc5uUEUAAAAAHBFgzyc9no20EC0e7A-_R0QFgww";
#      </script>
#      <style type="text/css">
#       #secondary_nav a,
# #secondary_nav a:link,
# #secondary_nav a:visited { color: #77c; text-decoration: none; }
# #secondary_nav a:hover { text-decoration: underline;  }
#
# .origin_site_link {
#     text-align: center;
#     padding:1em;
# }
#
# #footer-legal {
#     font-size: 9pt;
# }
#      </style>
#      <style type="text/css">
#       #links_and_seal {
#     justify-content: space-between;
#     align-items: center;
# }
#
# #secondary_nav {
#     white-space: normal;
# }
#
# .origin_site_link {
#     line-height: 2;
#     text-align: left;
#     font-size: 9;
#     padding: 0em;
# }
#
# #footer-legal {
#     line-height: 2;
# }
#      </style>
#      <!-- jobs -->
#      <div id="footerWrapper" role="contentinfo" style="text-align:center;">
#       <div id="footer" style="text-align:left;">
#        <div class="separator_bottom">
#        </div>
#        <div class="" id="secondary_nav">
#         <div id="links_and_seal">
#          <div id="footer_links">
#           <div id="core-links">
#            <a href="/" id="jobs_product_link" title="Jobs">
#             Jobs
#            </a>
#            -
#            <a href="/companies" id="companies_product_link" title="Browse Companies">
#             Browse Companies
#            </a>
#            -
#            <a href="/salaries" id="salaries_product_link" title="Salary Search">
#             Salaries
#            </a>
#            -
#            <script type="text/javascript">
#             var jobsProductLink = document.getElementById('jobs_product_link');
#                                 document.getElementById('companies_product_link').onclick = function() { window.location = '/Best-Places-to-Work?campaignid=jobs'; return false;};
#            </script>
#            <a href="/browsejobs">
#             Browse Jobs
#            </a>
#            -
#            <a href="http://www.indeed.jobs">
#             Work at Indeed
#            </a>
#            -
#            <a href="http://blog.au.indeed.com">
#             Blog
#            </a>
#            -
#            <a href="/intl/en/about.html">
#             <span style="white-space: nowrap;">
#              About
#             </span>
#            </a>
#            -
#            <a href="https://indeed.zendesk.com/hc/en-au">
#             Help Centre
#            </a>
#           </div>
#          </div>
#         </div>
#         <div id="footer-legal">
#          <div class="legal-footer">
#           © 2018 Indeed -
#           <a href="/legal">
#            Cookies, Privacy and Terms
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </td>
#    </tr>
#   </table>
#   <script type="text/javascript">
#    function sm_cv_tag(activityId) {
#             var ebRand = Math.random()+'';
#             ebRand = ebRand * 1000000;
#
#             var tagContainer = document.body.appendChild(document.createElement("div"));
#             tagContainer.style.position="absolute";
#             tagContainer.style.top="0";
#             tagContainer.style.left="0";
#             tagContainer.style.width="1px";
#             tagContainer.style.height="1px";
#             tagContainer.style.display="none";
#
#             var jsTag = document.createElement('script');
#             jsTag.src = '//bs.serving-sys.com/Serving/ActivityServer.bs?cn=as&ActivityID=' + activityId + '&rnd=' + ebRand;
#             jsTag.setAttribute('crossorigin', 'anonymous');
#             jsTag.style.width="1px";
#             jsTag.style.height="1px";
#             jsTag.style.border="0";
#             jsTag.async = 1;
#
#             var noScript = document.createElement("noscript");
#             var noScriptText = '<img width="1" height="1" style="border:0" src="//bs.serving-sys.com/Serving/ActivityServer.bs?cn=as&ActivityID=' + activityId + '&ns=1"/>';
#
#             // IE less than 9 and RCs do not support innerHTML on some DOM elements, but supports .text for it
#             if (((typeof noScript.canHaveHTML) === "boolean") && (noScript.canHaveHTML === false)) { // canHaveHTML only exists for IE
#                 noScript.text = noScriptText;
#             } else {
#                 noScript.innerHTML = noScriptText;
#             }
#
#             tagContainer.appendChild(jsTag);
#             tagContainer.appendChild(noScript);
#         }
#   </script>
#   <script type="text/javascript">
#    <!--
# logJSVPing('jsv', '1crciuptq108c002');
# function jsall_loaded() {
#
#
#     initProcessLeftoverDwellEntries();
#
#     detectBrowserState('jobsearch', '1crciuptq108c002');
#
#     initLogTiming('jobsearch', '1crciuptq108c002');
#
#     attachSjBlock('');
#     attachJaBlock('');
# }
# if (window['closureReady'] === true) {
#     jsall_loaded();
# }
# //-->
#   </script>
#   <script type="text/javascript">
#    PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
# PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];
#   </script>
#   <script type="text/javascript">
#    var ga_domains = [];
#         ga_domains.push('indeed.co.in');ga_domains.push('indeed.lu');ga_domains.push('indeed.fr');ga_domains.push('indeed.de');ga_domains.push('indeed.com.br');ga_domains.push('indeed.co.uk');ga_domains.push('indeed.hk');ga_domains.push('indeed.fi');ga_domains.push('indeed.pt');ga_domains.push('indeed.jp');ga_domains.push('indeed.com');ga_domains.push('indeed.com.sg');ga_domains.push('indeed.nl');ga_domains.push('indeed.com.pk');ga_domains.push('indeed.cl');ga_domains.push('indeed.es');ga_domains.push('indeed.co.ve');ga_domains.push('indeed.ae');ga_domains.push('indeed.com.mx');ga_domains.push('indeed.com.my');ga_domains.push('indeed.ch');ga_domains.push('indeed.com.co');ga_domains.push('indeed.com.ph');ga_domains.push('indeed.co.za');ga_domains.push('indeed.ie');ga_domains.push('indeed.com.au');ga_domains.push('indeed.ca');ga_domains.push('indeed.com.pe');
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r;
#             i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#             a = s.createElement(o),
#                     m = s.getElementsByTagName(o)[0];
#             a.async = 1;
#             a.src = g;
#             m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         var ga = ga || [];
#         ga('create', 'UA-90780-1', 'auto', {
#             'allowLinker': true
#         });
#         ga('require', 'linkid');
#         ga('require', 'linker');
#         ga('linker:autoLink', ga_domains, false, true);
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#
#
#         (function () {
#             if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
#                 for (var i in PENDING_ANALYTICS_VARS) {
#                     ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
#                 }
#             }
#         })();
#   </script>
#   <script>
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#             n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
#     fbq('init', '579216298929618');
#     fbq('track', "PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=579216298929618&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <script>
#    window._comscore = window._comscore || [];
# window._comscore.push({ c1: "2", c2: "6486505", c4:"au.indeed.com/data-scientist-jobs-in-Sydney-NSW", c15:"1crciupso108c000"});
# (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#   </script>
#   <noscript>
#    <img alt="" height="0" src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=6486505&amp;c4=au.indeed.com%2Fdata-scientist-jobs-in-Sydney-NSW&amp;c15=1crciupso108c000&amp;cv=2.0&amp;cj=1" style="display:none" width="0"/>
#   </noscript>
#  </body>
# </html>
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %% [markdown]
#  ### Function to get job title information
#  - pulling out all <div> tags with class including 'row'
#  - identifying <a> tags with attribute 'data-tn-element':'jobTitle'
#  - $for each <a> tags, find the value of attribute 'title'

# %%
def extract_job_title_from_result(soup):
    jobs = []
    for div in soup.findAll(name='div', attrs={'class':'row'}):
            for a in div.findAll(name='a', attrs={'data-tn-element':'jobTitle'}):
                jobs.append(a['title'])
    return(jobs)

extract_job_title_from_result(soup)
# Out:
# ['Data Scientist - Analytics',
#  'Data Scientist',
#  'Lead Data Scientist',
#  'Junior Data Scientist/ Machine Learning Engineer',
#  'Junior Data Scientist',
#  'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#  'Junior Data Scientist',
#  'Customer Facing Data Scientist',
#  'Data Scientist - Award-winning FinTech',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Ikon | Data Scientist',
#  'Data Scientist',
#  'Team Assistant with AI company']

# %% [markdown]
# ### Function to get Company Name information
# - pulling all <span> tags with 'class:'company' and 'class':'result-link-source'

# %%
def extract_company_from_result(soup):
    companies = []
    for div in soup.findAll(name='div', attrs={'class':'row'}):
        company = div.findAll(name='span', attrs={'class':'company'})
        if len(company) > 0:
            for b in company:
                companies.append(b.text.strip())
        else:
            sec_try = div.findAll(name='span', attrs={'class':'result-link-source'})
            for span in sec_try:
                companies.append(span.text.strip())
    return(companies)
extract_company_from_result(soup)
# Out:
# ['Domain Group',
#  'ANZ Banking Group',
#  'Domain Group',
#  'Intellify',
#  'The Eclair Group',
#  'Investigations & Counter Terrorism',
#  'Sirius People',
#  'DataRobot',
#  'Datasii',
#  'Freelancer.com',
#  'Freshwater Group',
#  'CPT Global',
#  'Ikon',
#  'News Corp Australia',
#  'HIVERY']

# %% [markdown]
# ### Function to get Location information
#
# - pulling all <span> tags with 'class:'location' use forloop on all span tags for text

# %%
def extract_location_from_result(soup):
    locations = []
    spans = soup.findAll('span', attrs={'class':'location'})
    for span in spans:
        locations.append(span.text)
    return(locations)

extract_location_from_result(soup)
# Out:
# ['Sydney NSW',
#  'Sydney NSW',
#  'Sydney NSW',
#  'Sydney Central Business District NSW',
#  'Sydney NSW',
#  'Sydney NSW',
#  'Sydney NSW',
#  'Sydney NSW',
#  'Sydney NSW',
#  'Sydney NSW']

# %% [markdown]
# ### Function to get Salary information
#
# - pulling span tags with class : no-wrap to get the salary

# %%
def extract_salary_from_result(soup):
    salary = ['none']
    spans = soup.findAll('span', attrs={'class':'no-wrap'})
    for span in spans:
        salary.append(span.text.strip())
    return salary

extract_salary_from_result(soup)
# Out:
# ['none',
#  'relevance -\n            date',
#  '$80,000 - $100,000 a year',
#  '$70,000 - $90,000 a year',
#  '$100,000 - $115,000 a year',
#  '$65,000 - $110,000 a year',
#  '$60,000 - $85,000 a year']

# %% [markdown]
# ### Function to get Job Summary Description

# %%
def extract_summary_from_result(soup):
    summaries = []
    spans = soup.findAll('span', attrs={'class':'summary'})
    for span in spans:
        summaries.append(span.text.strip())
    return(summaries)

extract_summary_from_result(soup)
# Out:
# ['As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#  'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#  'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#  'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#  'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#  'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#  'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#  'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#  'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#  'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#  'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#  'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#  'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#  'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#  'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...']

# %% [markdown]
# ### Putting it together to Scrape Data Science Job listing

# %% [markdown]
#  #### Create Empty Dataframe

# %%
max_results_per_city = 150
city_set = ["sydney+NSW","Ultimo+NSW","sydney+Western+Suburbs","Darlinghurst+NSW","Barangaroo+NSW",
            "Mascot+NSW","Parramatta+NSW","Surry+Hills+NSW","Macquarie+Park+NSW",
            "sydney+Inner+Suburbs+NSW","Hills+District+NSW","sydney+Central+Business+District+NSW",
            'New+South+Wales', 'Melbourne+VIC']
columns = ['city', 'job_title', 'company_name', 'location', 'summary', 'salary']
dsjob_df = pd.DataFrame(columns = columns)

# %%
a=[1,2,3,4,5,6]
a[0]=5
job_coll={}

# %%
for city in city_set:
    for start in range(0, max_results_per_city,1000):
        page = requests.get('https://au.indeed.com/jobs?q=data+scientist&l=' + '&start=' + str(start))
        time.sleep(1)
        for div in soup.findAll(name='div', attrs={'class':'row'}):
            # specify row num for index of job posting in dataframe
            num = (len(job_coll) + 1)
            
            # Create an empty list to hold data for each posting
            #job_post = ['None','None','None','None','None','None']
            job_post = ['city', 'job_title', 'company_name', 'location', 'summary', 'salary']
            # append city name
            job_post[0]=city
           
            # grab job title
            for a in div.findAll(name='a', attrs={'data-tn-element':'jobTitle'}):
                job_post[1]=a['title']
            
            # grap company name
            company = div.findAll(name='span', attrs={'class':'company'})
            if len(company) > 0:
                for b in company:
                    job_post[2]=(b.text.strip())
            else:
                sec_try = div.findAll(name='span', attrs= {'class': 'result-link-source'})
                for span in sec_try:
                    job_post[2]=(span.text)
                
            # grab location name
            c = div.findAll('span', attrs={'class':'location'})
            for span in c:
                job_post[3]=(span.text)
                    
            # grab summary text
            d = div.findAll('span', attrs={'class':'summary'})
            for span in d:
                job_post[4]=(span.text.strip())
                
            # grab salary
            e = div.findAll('span', attrs={'class':'no-wrap'})
            for span in e:
                job_post[5]=(span.text.strip())
                
            
            print ((job_post))
            
            job_coll[num]=job_post
# Out:
# ['sydney+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['sydney+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['sydney+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['sydney+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['sydney+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['sydney+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['sydney+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['sydney+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['sydney+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['sydney+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['sydney+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['sydney+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['sydney+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['sydney+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['sydney+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Ultimo+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Ultimo+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Ultimo+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Ultimo+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Ultimo+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Ultimo+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Ultimo+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Ultimo+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Ultimo+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Ultimo+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Ultimo+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Ultimo+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Ultimo+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Ultimo+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Ultimo+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['sydney+Western+Suburbs', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['sydney+Western+Suburbs', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['sydney+Western+Suburbs', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['sydney+Western+Suburbs', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['sydney+Western+Suburbs', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['sydney+Western+Suburbs', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['sydney+Western+Suburbs', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['sydney+Western+Suburbs', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['sydney+Western+Suburbs', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['sydney+Western+Suburbs', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['sydney+Western+Suburbs', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['sydney+Western+Suburbs', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['sydney+Western+Suburbs', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['sydney+Western+Suburbs', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['sydney+Western+Suburbs', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Darlinghurst+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Darlinghurst+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Darlinghurst+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Darlinghurst+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Darlinghurst+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Darlinghurst+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Darlinghurst+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Darlinghurst+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Darlinghurst+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Darlinghurst+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Darlinghurst+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Darlinghurst+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Darlinghurst+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Darlinghurst+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Darlinghurst+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Barangaroo+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Barangaroo+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Barangaroo+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Barangaroo+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Barangaroo+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Barangaroo+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Barangaroo+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Barangaroo+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Barangaroo+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Barangaroo+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Barangaroo+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Barangaroo+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Barangaroo+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Barangaroo+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Barangaroo+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Mascot+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Mascot+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Mascot+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Mascot+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Mascot+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Mascot+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Mascot+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Mascot+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Mascot+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Mascot+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Mascot+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Mascot+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Mascot+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Mascot+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Mascot+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Parramatta+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Parramatta+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Parramatta+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Parramatta+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Parramatta+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Parramatta+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Parramatta+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Parramatta+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Parramatta+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Parramatta+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Parramatta+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Parramatta+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Parramatta+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Parramatta+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Parramatta+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Surry+Hills+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Surry+Hills+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Surry+Hills+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Surry+Hills+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Surry+Hills+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Surry+Hills+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Surry+Hills+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Surry+Hills+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Surry+Hills+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Surry+Hills+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Surry+Hills+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Surry+Hills+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Surry+Hills+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Surry+Hills+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Surry+Hills+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Macquarie+Park+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Macquarie+Park+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Macquarie+Park+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Macquarie+Park+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Macquarie+Park+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Macquarie+Park+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Macquarie+Park+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Macquarie+Park+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Macquarie+Park+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Macquarie+Park+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Macquarie+Park+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Macquarie+Park+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Macquarie+Park+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Macquarie+Park+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Macquarie+Park+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['sydney+Inner+Suburbs+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['sydney+Inner+Suburbs+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['sydney+Inner+Suburbs+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['sydney+Inner+Suburbs+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['sydney+Inner+Suburbs+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['sydney+Inner+Suburbs+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Hills+District+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Hills+District+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Hills+District+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Hills+District+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Hills+District+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Hills+District+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Hills+District+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Hills+District+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Hills+District+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Hills+District+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Hills+District+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Hills+District+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Hills+District+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Hills+District+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Hills+District+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['sydney+Central+Business+District+NSW', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['sydney+Central+Business+District+NSW', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['sydney+Central+Business+District+NSW', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['sydney+Central+Business+District+NSW', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['sydney+Central+Business+District+NSW', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['sydney+Central+Business+District+NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['sydney+Central+Business+District+NSW', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['sydney+Central+Business+District+NSW', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['sydney+Central+Business+District+NSW', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['sydney+Central+Business+District+NSW', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['sydney+Central+Business+District+NSW', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['sydney+Central+Business+District+NSW', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['sydney+Central+Business+District+NSW', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['sydney+Central+Business+District+NSW', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['sydney+Central+Business+District+NSW', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['New+South+Wales', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['New+South+Wales', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['New+South+Wales', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['New+South+Wales', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['New+South+Wales', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['New+South+Wales', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['New+South+Wales', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['New+South+Wales', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['New+South+Wales', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['New+South+Wales', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['New+South+Wales', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['New+South+Wales', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['New+South+Wales', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['New+South+Wales', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['New+South+Wales', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']
# ['Melbourne+VIC', 'Data Scientist - Analytics', 'Domain Group', 'location', 'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...', 'salary']
# ['Melbourne+VIC', 'Data Scientist', 'ANZ Banking Group', 'location', 'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...', 'salary']
# ['Melbourne+VIC', 'Lead Data Scientist', 'Domain Group', 'location', 'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...', 'salary']
# ['Melbourne+VIC', 'Junior Data Scientist/ Machine Learning Engineer', 'Intellify', 'Sydney NSW', 'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...', '$80,000 - $100,000 a year']
# ['Melbourne+VIC', 'Junior Data Scientist', 'The Eclair Group', 'Sydney NSW', 'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....', '$70,000 - $90,000 a year']
# ['Melbourne+VIC', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force', 'Investigations & Counter Terrorism', 'Sydney NSW', 'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....', 'salary']
# ['Melbourne+VIC', 'Junior Data Scientist', 'Sirius People ', 'Sydney Central Business District NSW', 'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...', 'salary']
# ['Melbourne+VIC', 'Customer Facing Data Scientist', 'DataRobot', 'Sydney NSW', 'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...', 'salary']
# ['Melbourne+VIC', 'Data Scientist - Award-winning FinTech', 'Datasii', 'Sydney NSW', 'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....', '$100,000 - $115,000 a year']
# ['Melbourne+VIC', 'Data Scientist', 'Freelancer.com', 'Sydney NSW', 'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....', '$65,000 - $110,000 a year']
# ['Melbourne+VIC', 'Data Scientist', 'Freshwater Group', 'Sydney NSW', 'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...', 'salary']
# ['Melbourne+VIC', 'Data Scientist', 'CPT Global', 'Sydney NSW', 'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...', 'salary']
# ['Melbourne+VIC', 'Ikon | Data Scientist', 'Ikon', 'Sydney NSW', 'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....', 'salary']
# ['Melbourne+VIC', 'Data Scientist', 'News Corp Australia', 'location', 'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....', 'salary']
# ['Melbourne+VIC', 'Team Assistant with AI company', 'HIVERY', 'location', 'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...', '$60,000 - $85,000 a year']

# %%
len(job_coll)
# Out:
# 210

# %%
job_coll
# Out:
# {1: ['sydney+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  2: ['sydney+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  3: ['sydney+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  4: ['sydney+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  5: ['sydney+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  6: ['sydney+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  7: ['sydney+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  8: ['sydney+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  9: ['sydney+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  10: ['sydney+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  11: ['sydney+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  12: ['sydney+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  13: ['sydney+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  14: ['sydney+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  15: ['sydney+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  16: ['Ultimo+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  17: ['Ultimo+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  18: ['Ultimo+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  19: ['Ultimo+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  20: ['Ultimo+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  21: ['Ultimo+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  22: ['Ultimo+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  23: ['Ultimo+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  24: ['Ultimo+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  25: ['Ultimo+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  26: ['Ultimo+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  27: ['Ultimo+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  28: ['Ultimo+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  29: ['Ultimo+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  30: ['Ultimo+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  31: ['sydney+Western+Suburbs',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  32: ['sydney+Western+Suburbs',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  33: ['sydney+Western+Suburbs',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  34: ['sydney+Western+Suburbs',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  35: ['sydney+Western+Suburbs',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  36: ['sydney+Western+Suburbs',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  37: ['sydney+Western+Suburbs',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  38: ['sydney+Western+Suburbs',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  39: ['sydney+Western+Suburbs',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  40: ['sydney+Western+Suburbs',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  41: ['sydney+Western+Suburbs',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  42: ['sydney+Western+Suburbs',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  43: ['sydney+Western+Suburbs',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  44: ['sydney+Western+Suburbs',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  45: ['sydney+Western+Suburbs',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  46: ['Darlinghurst+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  47: ['Darlinghurst+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  48: ['Darlinghurst+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  49: ['Darlinghurst+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  50: ['Darlinghurst+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  51: ['Darlinghurst+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  52: ['Darlinghurst+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  53: ['Darlinghurst+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  54: ['Darlinghurst+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  55: ['Darlinghurst+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  56: ['Darlinghurst+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  57: ['Darlinghurst+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  58: ['Darlinghurst+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  59: ['Darlinghurst+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  60: ['Darlinghurst+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  61: ['Barangaroo+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  62: ['Barangaroo+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  63: ['Barangaroo+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  64: ['Barangaroo+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  65: ['Barangaroo+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  66: ['Barangaroo+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  67: ['Barangaroo+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  68: ['Barangaroo+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  69: ['Barangaroo+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  70: ['Barangaroo+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  71: ['Barangaroo+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  72: ['Barangaroo+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  73: ['Barangaroo+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  74: ['Barangaroo+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  75: ['Barangaroo+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  76: ['Mascot+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  77: ['Mascot+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  78: ['Mascot+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  79: ['Mascot+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  80: ['Mascot+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  81: ['Mascot+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  82: ['Mascot+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  83: ['Mascot+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  84: ['Mascot+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  85: ['Mascot+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  86: ['Mascot+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  87: ['Mascot+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  88: ['Mascot+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  89: ['Mascot+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  90: ['Mascot+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  91: ['Parramatta+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  92: ['Parramatta+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  93: ['Parramatta+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  94: ['Parramatta+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  95: ['Parramatta+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  96: ['Parramatta+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  97: ['Parramatta+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  98: ['Parramatta+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  99: ['Parramatta+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  100: ['Parramatta+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  101: ['Parramatta+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  102: ['Parramatta+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  103: ['Parramatta+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  104: ['Parramatta+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  105: ['Parramatta+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  106: ['Surry+Hills+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  107: ['Surry+Hills+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  108: ['Surry+Hills+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  109: ['Surry+Hills+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  110: ['Surry+Hills+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  111: ['Surry+Hills+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  112: ['Surry+Hills+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  113: ['Surry+Hills+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  114: ['Surry+Hills+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  115: ['Surry+Hills+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  116: ['Surry+Hills+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  117: ['Surry+Hills+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  118: ['Surry+Hills+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  119: ['Surry+Hills+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  120: ['Surry+Hills+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  121: ['Macquarie+Park+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  122: ['Macquarie+Park+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  123: ['Macquarie+Park+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  124: ['Macquarie+Park+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  125: ['Macquarie+Park+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  126: ['Macquarie+Park+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  127: ['Macquarie+Park+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  128: ['Macquarie+Park+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  129: ['Macquarie+Park+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  130: ['Macquarie+Park+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  131: ['Macquarie+Park+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  132: ['Macquarie+Park+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  133: ['Macquarie+Park+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  134: ['Macquarie+Park+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  135: ['Macquarie+Park+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  136: ['sydney+Inner+Suburbs+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  137: ['sydney+Inner+Suburbs+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  138: ['sydney+Inner+Suburbs+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  139: ['sydney+Inner+Suburbs+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  140: ['sydney+Inner+Suburbs+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  141: ['sydney+Inner+Suburbs+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  142: ['sydney+Inner+Suburbs+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  143: ['sydney+Inner+Suburbs+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  144: ['sydney+Inner+Suburbs+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  145: ['sydney+Inner+Suburbs+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  146: ['sydney+Inner+Suburbs+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  147: ['sydney+Inner+Suburbs+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  148: ['sydney+Inner+Suburbs+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  149: ['sydney+Inner+Suburbs+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  150: ['sydney+Inner+Suburbs+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  151: ['Hills+District+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  152: ['Hills+District+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  153: ['Hills+District+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  154: ['Hills+District+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  155: ['Hills+District+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  156: ['Hills+District+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  157: ['Hills+District+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  158: ['Hills+District+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  159: ['Hills+District+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  160: ['Hills+District+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  161: ['Hills+District+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  162: ['Hills+District+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  163: ['Hills+District+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  164: ['Hills+District+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  165: ['Hills+District+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  166: ['sydney+Central+Business+District+NSW',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  167: ['sydney+Central+Business+District+NSW',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  168: ['sydney+Central+Business+District+NSW',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  169: ['sydney+Central+Business+District+NSW',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  170: ['sydney+Central+Business+District+NSW',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  171: ['sydney+Central+Business+District+NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  172: ['sydney+Central+Business+District+NSW',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  173: ['sydney+Central+Business+District+NSW',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  174: ['sydney+Central+Business+District+NSW',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  175: ['sydney+Central+Business+District+NSW',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  176: ['sydney+Central+Business+District+NSW',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  177: ['sydney+Central+Business+District+NSW',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  178: ['sydney+Central+Business+District+NSW',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  179: ['sydney+Central+Business+District+NSW',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  180: ['sydney+Central+Business+District+NSW',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  181: ['New+South+Wales',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  182: ['New+South+Wales',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  183: ['New+South+Wales',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  184: ['New+South+Wales',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  185: ['New+South+Wales',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  186: ['New+South+Wales',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  187: ['New+South+Wales',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  188: ['New+South+Wales',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  189: ['New+South+Wales',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  190: ['New+South+Wales',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  191: ['New+South+Wales',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  192: ['New+South+Wales',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  193: ['New+South+Wales',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  194: ['New+South+Wales',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  195: ['New+South+Wales',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year'],
#  196: ['Melbourne+VIC',
#   'Data Scientist - Analytics',
#   'Domain Group',
#   'location',
#   'As a Data Scientist in our team, you will leverage your deep experience in statistics, machine learning and data analysis to drive significant improvements to...',
#   'salary'],
#  197: ['Melbourne+VIC',
#   'Data Scientist',
#   'ANZ Banking Group',
#   'location',
#   'As the Data Scientist, you are to source data from multiple data stores, and build advanced data models to solve complex problems and generate sophisticated...',
#   'salary'],
#  198: ['Melbourne+VIC',
#   'Lead Data Scientist',
#   'Domain Group',
#   'location',
#   'We are looking for a lead data scientist to help sales, product and business leadership make decisions with data, give consumers certainty and control when...',
#   'salary'],
#  199: ['Melbourne+VIC',
#   'Junior Data Scientist/ Machine Learning Engineer',
#   'Intellify',
#   'Sydney NSW',
#   'We also believe great data science comes from great teams, so invest continuously in upskilling and cross-training our data scientists, with lunch & learn...',
#   '$80,000 - $100,000 a year'],
#  200: ['Melbourne+VIC',
#   'Junior Data Scientist',
#   'The Eclair Group',
#   'Sydney NSW',
#   'Industry experience as a Data Analyst or Junior Data Scientist with a track record of manipulating, processing, and extracting value from large datasets....',
#   '$70,000 - $90,000 a year'],
#  201: ['Melbourne+VIC',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#   'Investigations & Counter Terrorism',
#   'Sydney NSW',
#   'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force. Experience with common data science toolkits, particularly R....',
#   'salary'],
#  202: ['Melbourne+VIC',
#   'Junior Data Scientist',
#   'Sirius People ',
#   'Sydney Central Business District NSW',
#   'Opportunity to start your career in Data Science Permanent role in Sydney CBD Be part of the brightest team I am currently looking for a few Junior Data...',
#   'salary'],
#  203: ['Melbourne+VIC',
#   'Customer Facing Data Scientist',
#   'DataRobot',
#   'Sydney NSW',
#   'Customer Facing Data Scientists work with the sales team to develop client relationships and deliver data science solutions for customers across a variety of...',
#   'salary'],
#  204: ['Melbourne+VIC',
#   'Data Scientist - Award-winning FinTech',
#   'Datasii',
#   'Sydney NSW',
#   'Experience as a Data Scientist (or a Data Analyst ready to step into a Data Scientist role) in the commercial environment....',
#   '$100,000 - $115,000 a year'],
#  205: ['Melbourne+VIC',
#   'Data Scientist',
#   'Freelancer.com',
#   'Sydney NSW',
#   'Proven experience as a data scientist or analyst. Experience in data mining. If this sounds like you, you will love life as a data scientist at Freelancer....',
#   '$65,000 - $110,000 a year'],
#  206: ['Melbourne+VIC',
#   'Data Scientist',
#   'Freshwater Group',
#   'Sydney NSW',
#   'The Data Scientist will:. Manage data sets. A Data Scientist is required for a wholesale electricity retailer that connects its customers to the wholesale...',
#   'salary'],
#  207: ['Melbourne+VIC',
#   'Data Scientist',
#   'CPT Global',
#   'Sydney NSW',
#   'Strong experience working as a Data Scientist. Experience of working with large data sets, statistical techniques and analysis – data mining, cleansing,...',
#   'salary'],
#  208: ['Melbourne+VIC',
#   'Ikon | Data Scientist',
#   'Ikon',
#   'Sydney NSW',
#   'Provide tangible support to Senior Data Scientists and the Data Science Manager in the preparation, analysis and visualization of data....',
#   'salary'],
#  209: ['Melbourne+VIC',
#   'Data Scientist',
#   'News Corp Australia',
#   'location',
#   'Undertake proactive analysis of customer data processes that produce data driven analysis, reporting, insights and models....',
#   'salary'],
#  210: ['Melbourne+VIC',
#   'Team Assistant with AI company',
#   'HIVERY',
#   'location',
#   'Our team of data scientists apply machine learning and sophisticated optimization techniques to develop simple-to-use solutions for the optimal business outcome...',
#   '$60,000 - $85,000 a year']}

# %% [markdown]
# ### Convert to Dataframe

# %%
ds_df = pd.DataFrame.from_dict(job_coll)

# %%
dsjob_df = ds_df.T

# %%
dsjob_df.head(3)
# Out:
#             0                           1                  2         3  \
# 1  sydney+NSW  Data Scientist - Analytics       Domain Group  location
# 2  sydney+NSW              Data Scientist  ANZ Banking Group  location
# 3  sydney+NSW         Lead Data Scientist       Domain Group  location
#
#                                                    4       5
# 1  As a Data Scientist in our team, you will leve...  salary
# 2  As the Data Scientist, you are to source data ...  salary
# 3  We are looking for a lead data scientist to he...  salary

# %%
dsjob_df.columns = ['city','job_title','company_name','location','summary','salary']

# %%
dsjob_df
# Out:
#                 city                                          job_title  \
# 1         sydney+NSW                         Data Scientist - Analytics
# 2         sydney+NSW                                     Data Scientist
# 3         sydney+NSW                                Lead Data Scientist
# 4         sydney+NSW   Junior Data Scientist/ Machine Learning Engineer
# 5         sydney+NSW                              Junior Data Scientist
# 6         sydney+NSW  Data Scientist - Complaint Services, Professio...
# 7         sydney+NSW                              Junior Data Scientist
# 8         sydney+NSW                     Customer Facing Data Scientist
# 9         sydney+NSW             Data Scientist - Award-winning FinTech
# 10        sydney+NSW                                     Data Scientist
# 11        sydney+NSW                                     Data Scientist
# 12        sydney+NSW                                     Data Scientist
# 13        sydney+NSW                              Ikon | Data Scientist
# 14        sydney+NSW                                     Data Scientist
# 15        sydney+NSW                     Team Assistant with AI company
# 16        Ultimo+NSW                         Data Scientist - Analytics
# 17        Ultimo+NSW                                     Data Scientist
# 18        Ultimo+NSW                                Lead Data Scientist
# 19        Ultimo+NSW   Junior Data Scientist/ Machine Learning Engineer
# 20        Ultimo+NSW                              Junior Data Scientist
# 21        Ultimo+NSW  Data Scientist - Complaint Services, Professio...
# 22        Ultimo+NSW                              Junior Data Scientist
# 23        Ultimo+NSW                     Customer Facing Data Scientist
# 24        Ultimo+NSW             Data Scientist - Award-winning FinTech
# 25        Ultimo+NSW                                     Data Scientist
# 26        Ultimo+NSW                                     Data Scientist
# 27        Ultimo+NSW                                     Data Scientist
# 28        Ultimo+NSW                              Ikon | Data Scientist
# 29        Ultimo+NSW                                     Data Scientist
# 30        Ultimo+NSW                     Team Assistant with AI company
# ..               ...                                                ...
# 181  New+South+Wales                         Data Scientist - Analytics
# 182  New+South+Wales                                     Data Scientist
# 183  New+South+Wales                                Lead Data Scientist
# 184  New+South+Wales   Junior Data Scientist/ Machine Learning Engineer
# 185  New+South+Wales                              Junior Data Scientist
# 186  New+South+Wales  Data Scientist - Complaint Services, Professio...
# 187  New+South+Wales                              Junior Data Scientist
# 188  New+South+Wales                     Customer Facing Data Scientist
# 189  New+South+Wales             Data Scientist - Award-winning FinTech
# 190  New+South+Wales                                     Data Scientist
# 191  New+South+Wales                                     Data Scientist
# 192  New+South+Wales                                     Data Scientist
# 193  New+South+Wales                              Ikon | Data Scientist
# 194  New+South+Wales                                     Data Scientist
# 195  New+South+Wales                     Team Assistant with AI company
# 196    Melbourne+VIC                         Data Scientist - Analytics
# 197    Melbourne+VIC                                     Data Scientist
# 198    Melbourne+VIC                                Lead Data Scientist
# 199    Melbourne+VIC   Junior Data Scientist/ Machine Learning Engineer
# 200    Melbourne+VIC                              Junior Data Scientist
# 201    Melbourne+VIC  Data Scientist - Complaint Services, Professio...
# 202    Melbourne+VIC                              Junior Data Scientist
# 203    Melbourne+VIC                     Customer Facing Data Scientist
# 204    Melbourne+VIC             Data Scientist - Award-winning FinTech
# 205    Melbourne+VIC                                     Data Scientist
# 206    Melbourne+VIC                                     Data Scientist
# 207    Melbourne+VIC                                     Data Scientist
# 208    Melbourne+VIC                              Ikon | Data Scientist
# 209    Melbourne+VIC                                     Data Scientist
# 210    Melbourne+VIC                     Team Assistant with AI company
#
#                            company_name                              location  \
# 1                          Domain Group                              location
# 2                     ANZ Banking Group                              location
# 3                          Domain Group                              location
# 4                             Intellify                            Sydney NSW
# 5                      The Eclair Group                            Sydney NSW
# 6    Investigations & Counter Terrorism                            Sydney NSW
# 7                        Sirius People   Sydney Central Business District NSW
# 8                             DataRobot                            Sydney NSW
# 9                               Datasii                            Sydney NSW
# 10                       Freelancer.com                            Sydney NSW
# 11                     Freshwater Group                            Sydney NSW
# 12                           CPT Global                            Sydney NSW
# 13                                 Ikon                            Sydney NSW
# 14                  News Corp Australia                              location
# 15                               HIVERY                              location
# 16                         Domain Group                              location
# 17                    ANZ Banking Group                              location
# 18                         Domain Group                              location
# 19                            Intellify                            Sydney NSW
# 20                     The Eclair Group                            Sydney NSW
# 21   Investigations & Counter Terrorism                            Sydney NSW
# 22                       Sirius People   Sydney Central Business District NSW
# 23                            DataRobot                            Sydney NSW
# 24                              Datasii                            Sydney NSW
# 25                       Freelancer.com                            Sydney NSW
# 26                     Freshwater Group                            Sydney NSW
# 27                           CPT Global                            Sydney NSW
# 28                                 Ikon                            Sydney NSW
# 29                  News Corp Australia                              location
# 30                               HIVERY                              location
# ..                                  ...                                   ...
# 181                        Domain Group                              location
# 182                   ANZ Banking Group                              location
# 183                        Domain Group                              location
# 184                           Intellify                            Sydney NSW
# 185                    The Eclair Group                            Sydney NSW
# 186  Investigations & Counter Terrorism                            Sydney NSW
# 187                      Sirius People   Sydney Central Business District NSW
# 188                           DataRobot                            Sydney NSW
# 189                             Datasii                            Sydney NSW
# 190                      Freelancer.com                            Sydney NSW
# 191                    Freshwater Group                            Sydney NSW
# 192                          CPT Global                            Sydney NSW
# 193                                Ikon                            Sydney NSW
# 194                 News Corp Australia                              location
# 195                              HIVERY                              location
# 196                        Domain Group                              location
# 197                   ANZ Banking Group                              location
# 198                        Domain Group                              location
# 199                           Intellify                            Sydney NSW
# 200                    The Eclair Group                            Sydney NSW
# 201  Investigations & Counter Terrorism                            Sydney NSW
# 202                      Sirius People   Sydney Central Business District NSW
# 203                           DataRobot                            Sydney NSW
# 204                             Datasii                            Sydney NSW
# 205                      Freelancer.com                            Sydney NSW
# 206                    Freshwater Group                            Sydney NSW
# 207                          CPT Global                            Sydney NSW
# 208                                Ikon                            Sydney NSW
# 209                 News Corp Australia                              location
# 210                              HIVERY                              location
#
#                                                summary  \
# 1    As a Data Scientist in our team, you will leve...
# 2    As the Data Scientist, you are to source data ...
# 3    We are looking for a lead data scientist to he...
# 4    We also believe great data science comes from ...
# 5    Industry experience as a Data Analyst or Junio...
# 6    Data Scientist - Complaint Services, Professio...
# 7    Opportunity to start your career in Data Scien...
# 8    Customer Facing Data Scientists work with the ...
# 9    Experience as a Data Scientist (or a Data Anal...
# 10   Proven experience as a data scientist or analy...
# 11   The Data Scientist will:. Manage data sets. A ...
# 12   Strong experience working as a Data Scientist....
# 13   Provide tangible support to Senior Data Scient...
# 14   Undertake proactive analysis of customer data ...
# 15   Our team of data scientists apply machine lear...
# 16   As a Data Scientist in our team, you will leve...
# 17   As the Data Scientist, you are to source data ...
# 18   We are looking for a lead data scientist to he...
# 19   We also believe great data science comes from ...
# 20   Industry experience as a Data Analyst or Junio...
# 21   Data Scientist - Complaint Services, Professio...
# 22   Opportunity to start your career in Data Scien...
# 23   Customer Facing Data Scientists work with the ...
# 24   Experience as a Data Scientist (or a Data Anal...
# 25   Proven experience as a data scientist or analy...
# 26   The Data Scientist will:. Manage data sets. A ...
# 27   Strong experience working as a Data Scientist....
# 28   Provide tangible support to Senior Data Scient...
# 29   Undertake proactive analysis of customer data ...
# 30   Our team of data scientists apply machine lear...
# ..                                                 ...
# 181  As a Data Scientist in our team, you will leve...
# 182  As the Data Scientist, you are to source data ...
# 183  We are looking for a lead data scientist to he...
# 184  We also believe great data science comes from ...
# 185  Industry experience as a Data Analyst or Junio...
# 186  Data Scientist - Complaint Services, Professio...
# 187  Opportunity to start your career in Data Scien...
# 188  Customer Facing Data Scientists work with the ...
# 189  Experience as a Data Scientist (or a Data Anal...
# 190  Proven experience as a data scientist or analy...
# 191  The Data Scientist will:. Manage data sets. A ...
# 192  Strong experience working as a Data Scientist....
# 193  Provide tangible support to Senior Data Scient...
# 194  Undertake proactive analysis of customer data ...
# 195  Our team of data scientists apply machine lear...
# 196  As a Data Scientist in our team, you will leve...
# 197  As the Data Scientist, you are to source data ...
# 198  We are looking for a lead data scientist to he...
# 199  We also believe great data science comes from ...
# 200  Industry experience as a Data Analyst or Junio...
# 201  Data Scientist - Complaint Services, Professio...
# 202  Opportunity to start your career in Data Scien...
# 203  Customer Facing Data Scientists work with the ...
# 204  Experience as a Data Scientist (or a Data Anal...
# 205  Proven experience as a data scientist or analy...
# 206  The Data Scientist will:. Manage data sets. A ...
# 207  Strong experience working as a Data Scientist....
# 208  Provide tangible support to Senior Data Scient...
# 209  Undertake proactive analysis of customer data ...
# 210  Our team of data scientists apply machine lear...
#
#                          salary
# 1                        salary
# 2                        salary
# 3                        salary
# 4     $80,000 - $100,000 a year
# 5      $70,000 - $90,000 a year
# 6                        salary
# 7                        salary
# 8                        salary
# 9    $100,000 - $115,000 a year
# 10    $65,000 - $110,000 a year
# 11                       salary
# 12                       salary
# 13                       salary
# 14                       salary
# 15     $60,000 - $85,000 a year
# 16                       salary
# 17                       salary
# 18                       salary
# 19    $80,000 - $100,000 a year
# 20     $70,000 - $90,000 a year
# 21                       salary
# 22                       salary
# 23                       salary
# 24   $100,000 - $115,000 a year
# 25    $65,000 - $110,000 a year
# 26                       salary
# 27                       salary
# 28                       salary
# 29                       salary
# 30     $60,000 - $85,000 a year
# ..                          ...
# 181                      salary
# 182                      salary
# 183                      salary
# 184   $80,000 - $100,000 a year
# 185    $70,000 - $90,000 a year
# 186                      salary
# 187                      salary
# 188                      salary
# 189  $100,000 - $115,000 a year
# 190   $65,000 - $110,000 a year
# 191                      salary
# 192                      salary
# 193                      salary
# 194                      salary
# 195    $60,000 - $85,000 a year
# 196                      salary
# 197                      salary
# 198                      salary
# 199   $80,000 - $100,000 a year
# 200    $70,000 - $90,000 a year
# 201                      salary
# 202                      salary
# 203                      salary
# 204  $100,000 - $115,000 a year
# 205   $65,000 - $110,000 a year
# 206                      salary
# 207                      salary
# 208                      salary
# 209                      salary
# 210    $60,000 - $85,000 a year
#
# [210 rows x 6 columns]

# %% [markdown]
# ### City and Location Column basically the same, Drop Location Column as City are more complete

# %%
dsjob_df = dsjob_df.drop(columns={'location'})

# %%
dsjob_df.head()
# Out:
#          city                                         job_title  \
# 1  sydney+NSW                        Data Scientist - Analytics
# 2  sydney+NSW                                    Data Scientist
# 3  sydney+NSW                               Lead Data Scientist
# 4  sydney+NSW  Junior Data Scientist/ Machine Learning Engineer
# 5  sydney+NSW                             Junior Data Scientist
#
#         company_name                                            summary  \
# 1       Domain Group  As a Data Scientist in our team, you will leve...
# 2  ANZ Banking Group  As the Data Scientist, you are to source data ...
# 3       Domain Group  We are looking for a lead data scientist to he...
# 4          Intellify  We also believe great data science comes from ...
# 5   The Eclair Group  Industry experience as a Data Analyst or Junio...
#
#                       salary
# 1                     salary
# 2                     salary
# 3                     salary
# 4  $80,000 - $100,000 a year
# 5   $70,000 - $90,000 a year

# %% [markdown]
# ### Clean City loacation

# %%
dsjob_df.city.unique()
# Out:
# array(['sydney+NSW', 'Ultimo+NSW', 'sydney+Western+Suburbs',
#        'Darlinghurst+NSW', 'Barangaroo+NSW', 'Mascot+NSW',
#        'Parramatta+NSW', 'Surry+Hills+NSW', 'Macquarie+Park+NSW',
#        'sydney+Inner+Suburbs+NSW', 'Hills+District+NSW',
#        'sydney+Central+Business+District+NSW', 'New+South+Wales',
#        'Melbourne+VIC'], dtype=object)

# %%
d = dsjob_df.replace('Sydney+W.+','Sydney', regex=True)

# %%
e = d.replace('Ulti.+','Ultimo', regex=True)

# %%
e = e.replace('syd.+','sydney', regex=True)

# %%
e = e.replace('Baran.+','Barangaroo', regex=True)

# %%
e = e.replace('Masc.+','Mascot', regex=True)

# %%
e = e.replace('Parr.+','Parramatta', regex=True)

# %%
e = e.replace('Surry .+','Surry Hills', regex=True)

# %%
e = e.replace('Macq.+','Macquarie Park', regex=True)

# %%
e = e.replace('Hill.+','Hills District', regex=True)

# %%
e = e.replace('New.+','Sydney', regex=True)

# %%
e = e.replace('Melb.+','Melbourne', regex=True)

# %%
e = e.replace('Darl.+','Darlinghurst', regex=True)

# %%
e = e.replace('Surry H.+','Surry Hills', regex=True)

# %%
e = e.replace('syd.+','Sydney', regex=True)

# %%
e.city.unique()
# Out:
# array(['Sydney', 'Ultimo', 'Darlinghurst', 'Barangaroo', 'Mascot',
#        'Parramatta', 'Surry Hills', 'Macquarie Park', 'Hills District',
#        'Melbourne'], dtype=object)

# %% [markdown]
# ### Clean Job Title

# %%
e.job_title.unique()
# Out:
# array(['Data Scientist - Analytics', 'Data Scientist',
#        'Lead Data Scientist',
#        'Junior Data Scientist/ Machine Learning Engineer',
#        'Junior Data Scientist',
#        'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#        'Customer Facing Data Scientist',
#        'Data Scientist - Award-winning FinTech', 'Ikon | Data Scientist',
#        'Team Assistant with AI company'], dtype=object)

# %%
e = e.replace('data.+','Data Scientist', regex=True)

# %%
e = e.replace('Lead.+', 'Senior Data Scientist', regex=True)

# %%
e = e.replace('Junior da.+', 'Junior Data Scientist', regex=True)

# %%
e = e.replace('Junior Data Analyst/Sci.+', 'Junior Data Scientist', regex=True)

# %%
e.job_title.unique()
# Out:
# array(['Data Scientist - Analytics', 'Data Scientist',
#        'Senior Data Scientist',
#        'Junior Data Scientist/ Machine Learning Engineer',
#        'Junior Data Scientist',
#        'Data Scientist - Complaint Services, Professional Standards Command, Redfern - NSW Police Force',
#        'Customer Facing Data Scientist',
#        'Data Scientist - Award-winning FinTech', 'Ikon | Data Scientist',
#        'Team Assistant with AI company'], dtype=object)

# %%
e = e.replace('Data Sc.+', 'Data Scientist', regex=True)

# %%
e = e.replace('Junior.+', 'Junior Data Scientist', regex=True)

# %%
e = e.replace('Custom.+', 'Data Scientist', regex=True)

# %%
e = e.replace('Team.+', 'Junior Data Scientist', regex=True)

# %%
e = e.replace('Ikon.+', 'Data Scientist', regex=True)

# %%
e.job_title.unique()
# Out:
# array(['Data Scientist', 'Senior Data Scientist', 'Junior Data Scientist'],
#       dtype=object)

# %%
e.head()
# Out:
#      city              job_title       company_name  \
# 1  Sydney         Data Scientist       Domain Group
# 2  Sydney         Data Scientist  ANZ Banking Group
# 3  Sydney  Senior Data Scientist       Domain Group
# 4  Sydney  Junior Data Scientist          Intellify
# 5  Sydney  Junior Data Scientist   The Eclair Group
#
#                                              summary  \
# 1                                As a Data Scientist
# 2                              As the Data Scientist
# 3           We are looking for a lead Data Scientist
# 4               We also believe great Data Scientist
# 5  Industry experience as a Data Analyst or Junio...
#
#                       salary
# 1                     salary
# 2                     salary
# 3                     salary
# 4  $80,000 - $100,000 a year
# 5   $70,000 - $90,000 a year

# %%
e = e.fillna(0)

# %%
e.head()
# Out:
#      city              job_title       company_name  \
# 1  Sydney         Data Scientist       Domain Group
# 2  Sydney         Data Scientist  ANZ Banking Group
# 3  Sydney  Senior Data Scientist       Domain Group
# 4  Sydney  Junior Data Scientist          Intellify
# 5  Sydney  Junior Data Scientist   The Eclair Group
#
#                                              summary  \
# 1                                As a Data Scientist
# 2                              As the Data Scientist
# 3           We are looking for a lead Data Scientist
# 4               We also believe great Data Scientist
# 5  Industry experience as a Data Analyst or Junio...
#
#                       salary
# 1                     salary
# 2                     salary
# 3                     salary
# 4  $80,000 - $100,000 a year
# 5   $70,000 - $90,000 a year

# %%
e.columns
# Out:
# Index(['city', 'job_title', 'company_name', 'summary', 'salary'], dtype='object')

# %%
e.to_csv('./data/dsjobx1.csv')

# %%
h_df = pd.read_csv('./data/dsjobx1.1.csv')

# %%
h_df.head()
# Out:
#      city              job_title       company_name  \
# 0  Sydney         Data Scientist       Domain Group
# 1  Sydney         Data Scientist  ANZ Banking Group
# 2  Sydney  Senior Data Scientist       Domain Group
# 3  Sydney  Junior Data Scientist          Intellify
# 4  Sydney  Junior Data Scientist   The Eclair Group
#
#                                              summary salary_lower salary_upper
# 0                                As a Data Scientist       salary          NaN
# 1                              As the Data Scientist       salary          NaN
# 2           We are looking for a lead Data Scientist       salary          NaN
# 3               We also believe great Data Scientist      $80,000     $100,000
# 4  Industry experience as a Data Analyst or Junio...      $70,000      $90,000

# %%
h_df.salary_lower.replace('salary', 0, inplace=True)

# %%
h_df.salary_lower.replace('[$,]', '', regex=True, inplace=True)

# %%
h_df.salary_upper.replace('[A-z$,]', '', regex=True, inplace=True)

# %%
h_df.head()
# Out:
#      city              job_title       company_name  \
# 0  Sydney         Data Scientist       Domain Group
# 1  Sydney         Data Scientist  ANZ Banking Group
# 2  Sydney  Senior Data Scientist       Domain Group
# 3  Sydney  Junior Data Scientist          Intellify
# 4  Sydney  Junior Data Scientist   The Eclair Group
#
#                                              summary salary_lower salary_upper
# 0                                As a Data Scientist            0          NaN
# 1                              As the Data Scientist            0          NaN
# 2           We are looking for a lead Data Scientist            0          NaN
# 3               We also believe great Data Scientist        80000       100000
# 4  Industry experience as a Data Analyst or Junio...        70000        90000

# %%
h_df[['salary_lower', 'salary_upper']] = h_df[['salary_lower', 'salary_upper']].astype('float64')

# %%
h_df.dtypes
# Out:
# city             object
# job_title        object
# company_name     object
# summary          object
# salary_lower    float64
# salary_upper    float64
# dtype: object

# %% [markdown]
# Replace 0 back to NAN as it cannot calculate the Median.

# %%
j_df = h_df.replace(0, np.nan)

# %%
j_df.head()
# Out:
#      city              job_title       company_name  \
# 0  Sydney         Data Scientist       Domain Group
# 1  Sydney         Data Scientist  ANZ Banking Group
# 2  Sydney  Senior Data Scientist       Domain Group
# 3  Sydney  Junior Data Scientist          Intellify
# 4  Sydney  Junior Data Scientist   The Eclair Group
#
#                                              summary  salary_lower  \
# 0                                As a Data Scientist           NaN
# 1                              As the Data Scientist           NaN
# 2           We are looking for a lead Data Scientist           NaN
# 3               We also believe great Data Scientist       80000.0
# 4  Industry experience as a Data Analyst or Junio...       70000.0
#
#    salary_upper
# 0           NaN
# 1           NaN
# 2           NaN
# 3      100000.0
# 4       90000.0

# %%
j_df['median_salary_lower'] = j_df.groupby('job_title')['salary_lower'].transform('median')

# %%
j_df['median_salary_upper'] = j_df.groupby('job_title')['salary_upper'].transform('median')

# %%
j_df.head()
# Out:
#      city              job_title       company_name  \
# 0  Sydney         Data Scientist       Domain Group
# 1  Sydney         Data Scientist  ANZ Banking Group
# 2  Sydney  Senior Data Scientist       Domain Group
# 3  Sydney  Junior Data Scientist          Intellify
# 4  Sydney  Junior Data Scientist   The Eclair Group
#
#                                              summary  salary_lower  \
# 0                                As a Data Scientist           NaN
# 1                              As the Data Scientist           NaN
# 2           We are looking for a lead Data Scientist           NaN
# 3               We also believe great Data Scientist       80000.0
# 4  Industry experience as a Data Analyst or Junio...       70000.0
#
#    salary_upper  median_salary_lower  median_salary_upper
# 0           NaN              82500.0             112500.0
# 1           NaN              82500.0             112500.0
# 2           NaN                  NaN                  NaN
# 3      100000.0              70000.0              90000.0
# 4       90000.0              70000.0              90000.0

# %%
j_df.salary_lower.fillna(j_df.median_salary_lower, inplace=True)

# %%
j_df.salary_upper.fillna(j_df.median_salary_upper, inplace=True)

# %%
j_df.dropna()
# Out:
#           city              job_title                        company_name  \
# 0       Sydney         Data Scientist                        Domain Group
# 1       Sydney         Data Scientist                   ANZ Banking Group
# 3       Sydney  Junior Data Scientist                           Intellify
# 4       Sydney  Junior Data Scientist                    The Eclair Group
# 5       Sydney         Data Scientist  Investigations & Counter Terrorism
# 6       Sydney  Junior Data Scientist                      Sirius People
# 7       Sydney         Data Scientist                           DataRobot
# 8       Sydney         Data Scientist                             Datasii
# 9       Sydney         Data Scientist                      Freelancer.com
# 10      Sydney         Data Scientist                    Freshwater Group
# 11      Sydney         Data Scientist                          CPT Global
# 12      Sydney         Data Scientist                                Ikon
# 13      Sydney         Data Scientist                              Sydney
# 14      Sydney  Junior Data Scientist                              HIVERY
# 15      Ultimo         Data Scientist                        Domain Group
# 16      Ultimo         Data Scientist                   ANZ Banking Group
# 18      Ultimo  Junior Data Scientist                           Intellify
# 19      Ultimo  Junior Data Scientist                    The Eclair Group
# 20      Ultimo         Data Scientist  Investigations & Counter Terrorism
# 21      Ultimo  Junior Data Scientist                      Sirius People
# 22      Ultimo         Data Scientist                           DataRobot
# 23      Ultimo         Data Scientist                             Datasii
# 24      Ultimo         Data Scientist                      Freelancer.com
# 25      Ultimo         Data Scientist                    Freshwater Group
# 26      Ultimo         Data Scientist                          CPT Global
# 27      Ultimo         Data Scientist                                Ikon
# 28      Ultimo         Data Scientist                              Sydney
# 29      Ultimo  Junior Data Scientist                              HIVERY
# 30      Sydney         Data Scientist                        Domain Group
# 31      Sydney         Data Scientist                   ANZ Banking Group
# ..         ...                    ...                                 ...
# 178     Sydney         Data Scientist                              Sydney
# 179     Sydney  Junior Data Scientist                              HIVERY
# 180     Sydney         Data Scientist                        Domain Group
# 181     Sydney         Data Scientist                   ANZ Banking Group
# 183     Sydney  Junior Data Scientist                           Intellify
# 184     Sydney  Junior Data Scientist                    The Eclair Group
# 185     Sydney         Data Scientist  Investigations & Counter Terrorism
# 186     Sydney  Junior Data Scientist                      Sirius People
# 187     Sydney         Data Scientist                           DataRobot
# 188     Sydney         Data Scientist                             Datasii
# 189     Sydney         Data Scientist                      Freelancer.com
# 190     Sydney         Data Scientist                    Freshwater Group
# 191     Sydney         Data Scientist                          CPT Global
# 192     Sydney         Data Scientist                                Ikon
# 193     Sydney         Data Scientist                              Sydney
# 194     Sydney  Junior Data Scientist                              HIVERY
# 195  Melbourne         Data Scientist                        Domain Group
# 196  Melbourne         Data Scientist                   ANZ Banking Group
# 198  Melbourne  Junior Data Scientist                           Intellify
# 199  Melbourne  Junior Data Scientist                    The Eclair Group
# 200  Melbourne         Data Scientist  Investigations & Counter Terrorism
# 201  Melbourne  Junior Data Scientist                      Sirius People
# 202  Melbourne         Data Scientist                           DataRobot
# 203  Melbourne         Data Scientist                             Datasii
# 204  Melbourne         Data Scientist                      Freelancer.com
# 205  Melbourne         Data Scientist                    Freshwater Group
# 206  Melbourne         Data Scientist                          CPT Global
# 207  Melbourne         Data Scientist                                Ikon
# 208  Melbourne         Data Scientist                              Sydney
# 209  Melbourne  Junior Data Scientist                              HIVERY
#
#                                                summary  salary_lower  \
# 0                                  As a Data Scientist       82500.0
# 1                                As the Data Scientist       82500.0
# 3                 We also believe great Data Scientist       80000.0
# 4    Industry experience as a Data Analyst or Junio...       70000.0
# 5                                       Data Scientist       82500.0
# 6    Opportunity to start your career in Data Scien...       70000.0
# 7                                       Data Scientist       82500.0
# 8                       Experience as a Data Scientist      100000.0
# 9                Proven experience as a Data Scientist       65000.0
# 10                                  The Data Scientist       82500.0
# 11       Strong experience working as a Data Scientist       82500.0
# 12   Provide tangible support to Senior Data Scientist       82500.0
# 13   Undertake proactive analysis of customer Data ...       82500.0
# 14                          Our team of Data Scientist       60000.0
# 15                                 As a Data Scientist       82500.0
# 16                               As the Data Scientist       82500.0
# 18                We also believe great Data Scientist       80000.0
# 19   Industry experience as a Data Analyst or Junio...       70000.0
# 20                                      Data Scientist       82500.0
# 21   Opportunity to start your career in Data Scien...       70000.0
# 22                                      Data Scientist       82500.0
# 23                      Experience as a Data Scientist      100000.0
# 24               Proven experience as a Data Scientist       65000.0
# 25                                  The Data Scientist       82500.0
# 26       Strong experience working as a Data Scientist       82500.0
# 27   Provide tangible support to Senior Data Scientist       82500.0
# 28   Undertake proactive analysis of customer Data ...       82500.0
# 29                          Our team of Data Scientist       60000.0
# 30                                 As a Data Scientist       82500.0
# 31                               As the Data Scientist       82500.0
# ..                                                 ...           ...
# 178  Undertake proactive analysis of customer Data ...       82500.0
# 179                         Our team of Data Scientist       60000.0
# 180                                As a Data Scientist       82500.0
# 181                              As the Data Scientist       82500.0
# 183               We also believe great Data Scientist       80000.0
# 184  Industry experience as a Data Analyst or Junio...       70000.0
# 185                                     Data Scientist       82500.0
# 186  Opportunity to start your career in Data Scien...       70000.0
# 187                                     Data Scientist       82500.0
# 188                     Experience as a Data Scientist      100000.0
# 189              Proven experience as a Data Scientist       65000.0
# 190                                 The Data Scientist       82500.0
# 191      Strong experience working as a Data Scientist       82500.0
# 192  Provide tangible support to Senior Data Scientist       82500.0
# 193  Undertake proactive analysis of customer Data ...       82500.0
# 194                         Our team of Data Scientist       60000.0
# 195                                As a Data Scientist       82500.0
# 196                              As the Data Scientist       82500.0
# 198               We also believe great Data Scientist       80000.0
# 199  Industry experience as a Data Analyst or Junio...       70000.0
# 200                                     Data Scientist       82500.0
# 201  Opportunity to start your career in Data Scien...       70000.0
# 202                                     Data Scientist       82500.0
# 203                     Experience as a Data Scientist      100000.0
# 204              Proven experience as a Data Scientist       65000.0
# 205                                 The Data Scientist       82500.0
# 206      Strong experience working as a Data Scientist       82500.0
# 207  Provide tangible support to Senior Data Scientist       82500.0
# 208  Undertake proactive analysis of customer Data ...       82500.0
# 209                         Our team of Data Scientist       60000.0
#
#      salary_upper  median_salary_lower  median_salary_upper
# 0        112500.0              82500.0             112500.0
# 1        112500.0              82500.0             112500.0
# 3        100000.0              70000.0              90000.0
# 4         90000.0              70000.0              90000.0
# 5        112500.0              82500.0             112500.0
# 6         90000.0              70000.0              90000.0
# 7        112500.0              82500.0             112500.0
# 8        115000.0              82500.0             112500.0
# 9        110000.0              82500.0             112500.0
# 10       112500.0              82500.0             112500.0
# 11       112500.0              82500.0             112500.0
# 12       112500.0              82500.0             112500.0
# 13       112500.0              82500.0             112500.0
# 14        85000.0              70000.0              90000.0
# 15       112500.0              82500.0             112500.0
# 16       112500.0              82500.0             112500.0
# 18       100000.0              70000.0              90000.0
# 19        90000.0              70000.0              90000.0
# 20       112500.0              82500.0             112500.0
# 21        90000.0              70000.0              90000.0
# 22       112500.0              82500.0             112500.0
# 23       115000.0              82500.0             112500.0
# 24       110000.0              82500.0             112500.0
# 25       112500.0              82500.0             112500.0
# 26       112500.0              82500.0             112500.0
# 27       112500.0              82500.0             112500.0
# 28       112500.0              82500.0             112500.0
# 29        85000.0              70000.0              90000.0
# 30       112500.0              82500.0             112500.0
# 31       112500.0              82500.0             112500.0
# ..            ...                  ...                  ...
# 178      112500.0              82500.0             112500.0
# 179       85000.0              70000.0              90000.0
# 180      112500.0              82500.0             112500.0
# 181      112500.0              82500.0             112500.0
# 183      100000.0              70000.0              90000.0
# 184       90000.0              70000.0              90000.0
# 185      112500.0              82500.0             112500.0
# 186       90000.0              70000.0              90000.0
# 187      112500.0              82500.0             112500.0
# 188      115000.0              82500.0             112500.0
# 189      110000.0              82500.0             112500.0
# 190      112500.0              82500.0             112500.0
# 191      112500.0              82500.0             112500.0
# 192      112500.0              82500.0             112500.0
# 193      112500.0              82500.0             112500.0
# 194       85000.0              70000.0              90000.0
# 195      112500.0              82500.0             112500.0
# 196      112500.0              82500.0             112500.0
# 198      100000.0              70000.0              90000.0
# 199       90000.0              70000.0              90000.0
# 200      112500.0              82500.0             112500.0
# 201       90000.0              70000.0              90000.0
# 202      112500.0              82500.0             112500.0
# 203      115000.0              82500.0             112500.0
# 204      110000.0              82500.0             112500.0
# 205      112500.0              82500.0             112500.0
# 206      112500.0              82500.0             112500.0
# 207      112500.0              82500.0             112500.0
# 208      112500.0              82500.0             112500.0
# 209       85000.0              70000.0              90000.0
#
# [196 rows x 8 columns]

# %% [markdown]
# Drop the last 2 Column

# %%
j_df.to_csv('./data/dsfinal.csv')

# %%
h_df = pd.read_csv('./data/dsfinal.csv')

# %%
h_df['mean_salary'] = (j_df.salary_lower + j_df.salary_upper) / 2

# %%
h_df.dropna()
# Out:
#      Unnamed: 0       city              job_title  \
# 0             0     Sydney         Data Scientist
# 1             1     Sydney         Data Scientist
# 3             3     Sydney  Junior Data Scientist
# 4             4     Sydney  Junior Data Scientist
# 5             5     Sydney         Data Scientist
# 6             6     Sydney  Junior Data Scientist
# 7             7     Sydney         Data Scientist
# 8             8     Sydney         Data Scientist
# 9             9     Sydney         Data Scientist
# 10           10     Sydney         Data Scientist
# 11           11     Sydney         Data Scientist
# 12           12     Sydney         Data Scientist
# 13           13     Sydney         Data Scientist
# 14           14     Sydney  Junior Data Scientist
# 15           15     Ultimo         Data Scientist
# 16           16     Ultimo         Data Scientist
# 18           18     Ultimo  Junior Data Scientist
# 19           19     Ultimo  Junior Data Scientist
# 20           20     Ultimo         Data Scientist
# 21           21     Ultimo  Junior Data Scientist
# 22           22     Ultimo         Data Scientist
# 23           23     Ultimo         Data Scientist
# 24           24     Ultimo         Data Scientist
# 25           25     Ultimo         Data Scientist
# 26           26     Ultimo         Data Scientist
# 27           27     Ultimo         Data Scientist
# 28           28     Ultimo         Data Scientist
# 29           29     Ultimo  Junior Data Scientist
# 30           30     Sydney         Data Scientist
# 31           31     Sydney         Data Scientist
# ..          ...        ...                    ...
# 178         178     Sydney         Data Scientist
# 179         179     Sydney  Junior Data Scientist
# 180         180     Sydney         Data Scientist
# 181         181     Sydney         Data Scientist
# 183         183     Sydney  Junior Data Scientist
# 184         184     Sydney  Junior Data Scientist
# 185         185     Sydney         Data Scientist
# 186         186     Sydney  Junior Data Scientist
# 187         187     Sydney         Data Scientist
# 188         188     Sydney         Data Scientist
# 189         189     Sydney         Data Scientist
# 190         190     Sydney         Data Scientist
# 191         191     Sydney         Data Scientist
# 192         192     Sydney         Data Scientist
# 193         193     Sydney         Data Scientist
# 194         194     Sydney  Junior Data Scientist
# 195         195  Melbourne         Data Scientist
# 196         196  Melbourne         Data Scientist
# 198         198  Melbourne  Junior Data Scientist
# 199         199  Melbourne  Junior Data Scientist
# 200         200  Melbourne         Data Scientist
# 201         201  Melbourne  Junior Data Scientist
# 202         202  Melbourne         Data Scientist
# 203         203  Melbourne         Data Scientist
# 204         204  Melbourne         Data Scientist
# 205         205  Melbourne         Data Scientist
# 206         206  Melbourne         Data Scientist
# 207         207  Melbourne         Data Scientist
# 208         208  Melbourne         Data Scientist
# 209         209  Melbourne  Junior Data Scientist
#
#                            company_name  \
# 0                          Domain Group
# 1                     ANZ Banking Group
# 3                             Intellify
# 4                      The Eclair Group
# 5    Investigations & Counter Terrorism
# 6                        Sirius People
# 7                             DataRobot
# 8                               Datasii
# 9                        Freelancer.com
# 10                     Freshwater Group
# 11                           CPT Global
# 12                                 Ikon
# 13                               Sydney
# 14                               HIVERY
# 15                         Domain Group
# 16                    ANZ Banking Group
# 18                            Intellify
# 19                     The Eclair Group
# 20   Investigations & Counter Terrorism
# 21                       Sirius People
# 22                            DataRobot
# 23                              Datasii
# 24                       Freelancer.com
# 25                     Freshwater Group
# 26                           CPT Global
# 27                                 Ikon
# 28                               Sydney
# 29                               HIVERY
# 30                         Domain Group
# 31                    ANZ Banking Group
# ..                                  ...
# 178                              Sydney
# 179                              HIVERY
# 180                        Domain Group
# 181                   ANZ Banking Group
# 183                           Intellify
# 184                    The Eclair Group
# 185  Investigations & Counter Terrorism
# 186                      Sirius People
# 187                           DataRobot
# 188                             Datasii
# 189                      Freelancer.com
# 190                    Freshwater Group
# 191                          CPT Global
# 192                                Ikon
# 193                              Sydney
# 194                              HIVERY
# 195                        Domain Group
# 196                   ANZ Banking Group
# 198                           Intellify
# 199                    The Eclair Group
# 200  Investigations & Counter Terrorism
# 201                      Sirius People
# 202                           DataRobot
# 203                             Datasii
# 204                      Freelancer.com
# 205                    Freshwater Group
# 206                          CPT Global
# 207                                Ikon
# 208                              Sydney
# 209                              HIVERY
#
#                                                summary  salary_lower  \
# 0                                  As a Data Scientist       82500.0
# 1                                As the Data Scientist       82500.0
# 3                 We also believe great Data Scientist       80000.0
# 4    Industry experience as a Data Analyst or Junio...       70000.0
# 5                                       Data Scientist       82500.0
# 6    Opportunity to start your career in Data Scien...       70000.0
# 7                                       Data Scientist       82500.0
# 8                       Experience as a Data Scientist      100000.0
# 9                Proven experience as a Data Scientist       65000.0
# 10                                  The Data Scientist       82500.0
# 11       Strong experience working as a Data Scientist       82500.0
# 12   Provide tangible support to Senior Data Scientist       82500.0
# 13   Undertake proactive analysis of customer Data ...       82500.0
# 14                          Our team of Data Scientist       60000.0
# 15                                 As a Data Scientist       82500.0
# 16                               As the Data Scientist       82500.0
# 18                We also believe great Data Scientist       80000.0
# 19   Industry experience as a Data Analyst or Junio...       70000.0
# 20                                      Data Scientist       82500.0
# 21   Opportunity to start your career in Data Scien...       70000.0
# 22                                      Data Scientist       82500.0
# 23                      Experience as a Data Scientist      100000.0
# 24               Proven experience as a Data Scientist       65000.0
# 25                                  The Data Scientist       82500.0
# 26       Strong experience working as a Data Scientist       82500.0
# 27   Provide tangible support to Senior Data Scientist       82500.0
# 28   Undertake proactive analysis of customer Data ...       82500.0
# 29                          Our team of Data Scientist       60000.0
# 30                                 As a Data Scientist       82500.0
# 31                               As the Data Scientist       82500.0
# ..                                                 ...           ...
# 178  Undertake proactive analysis of customer Data ...       82500.0
# 179                         Our team of Data Scientist       60000.0
# 180                                As a Data Scientist       82500.0
# 181                              As the Data Scientist       82500.0
# 183               We also believe great Data Scientist       80000.0
# 184  Industry experience as a Data Analyst or Junio...       70000.0
# 185                                     Data Scientist       82500.0
# 186  Opportunity to start your career in Data Scien...       70000.0
# 187                                     Data Scientist       82500.0
# 188                     Experience as a Data Scientist      100000.0
# 189              Proven experience as a Data Scientist       65000.0
# 190                                 The Data Scientist       82500.0
# 191      Strong experience working as a Data Scientist       82500.0
# 192  Provide tangible support to Senior Data Scientist       82500.0
# 193  Undertake proactive analysis of customer Data ...       82500.0
# 194                         Our team of Data Scientist       60000.0
# 195                                As a Data Scientist       82500.0
# 196                              As the Data Scientist       82500.0
# 198               We also believe great Data Scientist       80000.0
# 199  Industry experience as a Data Analyst or Junio...       70000.0
# 200                                     Data Scientist       82500.0
# 201  Opportunity to start your career in Data Scien...       70000.0
# 202                                     Data Scientist       82500.0
# 203                     Experience as a Data Scientist      100000.0
# 204              Proven experience as a Data Scientist       65000.0
# 205                                 The Data Scientist       82500.0
# 206      Strong experience working as a Data Scientist       82500.0
# 207  Provide tangible support to Senior Data Scientist       82500.0
# 208  Undertake proactive analysis of customer Data ...       82500.0
# 209                         Our team of Data Scientist       60000.0
#
#      salary_upper  mean_salary
# 0        112500.0      97500.0
# 1        112500.0      97500.0
# 3        100000.0      90000.0
# 4         90000.0      80000.0
# 5        112500.0      97500.0
# 6         90000.0      80000.0
# 7        112500.0      97500.0
# 8        115000.0     107500.0
# 9        110000.0      87500.0
# 10       112500.0      97500.0
# 11       112500.0      97500.0
# 12       112500.0      97500.0
# 13       112500.0      97500.0
# 14        85000.0      72500.0
# 15       112500.0      97500.0
# 16       112500.0      97500.0
# 18       100000.0      90000.0
# 19        90000.0      80000.0
# 20       112500.0      97500.0
# 21        90000.0      80000.0
# 22       112500.0      97500.0
# 23       115000.0     107500.0
# 24       110000.0      87500.0
# 25       112500.0      97500.0
# 26       112500.0      97500.0
# 27       112500.0      97500.0
# 28       112500.0      97500.0
# 29        85000.0      72500.0
# 30       112500.0      97500.0
# 31       112500.0      97500.0
# ..            ...          ...
# 178      112500.0      97500.0
# 179       85000.0      72500.0
# 180      112500.0      97500.0
# 181      112500.0      97500.0
# 183      100000.0      90000.0
# 184       90000.0      80000.0
# 185      112500.0      97500.0
# 186       90000.0      80000.0
# 187      112500.0      97500.0
# 188      115000.0     107500.0
# 189      110000.0      87500.0
# 190      112500.0      97500.0
# 191      112500.0      97500.0
# 192      112500.0      97500.0
# 193      112500.0      97500.0
# 194       85000.0      72500.0
# 195      112500.0      97500.0
# 196      112500.0      97500.0
# 198      100000.0      90000.0
# 199       90000.0      80000.0
# 200      112500.0      97500.0
# 201       90000.0      80000.0
# 202      112500.0      97500.0
# 203      115000.0     107500.0
# 204      110000.0      87500.0
# 205      112500.0      97500.0
# 206      112500.0      97500.0
# 207      112500.0      97500.0
# 208      112500.0      97500.0
# 209       85000.0      72500.0
#
# [196 rows x 8 columns]

# %%
h_df.to_csv('./data/dsfinal2.csv')
